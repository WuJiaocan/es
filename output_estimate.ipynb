# %%
# '''
#     CRF++预测之后的结果，每行直接就是以\t划分的三列
# '''
# output = open('./result_1.txt','r',encoding='utf-8')
# pairList = []
# result = []
# for line in output:
#     line = line.encode('utf-8').decode('utf-8-sig').strip()
#     if line:
#         if len(line.split("\t")) == 3:
#             l = line.split('\t')
#             word = l[0]
#             true_pos = l[1]
#             pred_pos = l[2]
# #             if word != "。":
#             pairList.append([word, true_pos, pred_pos])
# #                 print(pairList)
# #             else:
# #                 result.append(pairList)
# #                 pairList = []
# output.close()

# %% [markdown]
# #### result1.txt
# #### 结果来自trainData1Exp.txt，（0.txt -- 3878.txt）的训练，-f 8
# #### testData1Exp.txt，（38779.txt -- 42471.txt）的测试，
# #### 其中训练集和测试集完全取决于百度的分词结果，上传的分词库为1405行（初始版）的title分词库

# %%
'''
    这次写出来的结果，三列数据写成了两行，第一行是 word \t truePos，第二行是predictedPos。
    
    不知为啥格式变了。
'''
new_result = open('./result_1_NewFormat.txt','w',encoding='utf-8')
output = open('./result_1.txt','r',encoding='utf-8')
pairList = []
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        if "\t" in line:
            line = line.split("\t")
            tmp_1 = line
        else:
            pair = tmp_1[0] + " " + tmp_1[1] + " " +line
            new_result.write(tmp_1[0] + " " + tmp_1[1] + " " + line + "\r\n")
            pairList.append(pair)
output.close()
new_result.close()

# %%
recallTotal_T = 0
precisionTotal_T = 0
correctTotal_T = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == ('nr' or 'nt' or 'ti'):
        recallTotal_T += 1

    if pair[2] == ('nr' or 'nt' or 'ti'):
        precisionTotal_T += 1

    if pair[1] == pair[2] and pair[1]==('nr' or 'nt' or 'ti'):
        correctTotal_T += 1  
            
precisionRate_T = 1.0 * correctTotal_T / precisionTotal_T
recallRate_T = 1.0 * correctTotal_T / recallTotal_T
F_T = 2 / (1/precisionRate_T + 1/recallRate_T)

'''
    nr nt ti总的加一起
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_T:', precisionRate_T)  # 0.824242825899662
print('recallRate_T:', recallRate_T)        # 0.6441238010399619
print('F_T:',F_T)                          # 0.7231360509805974
# Out:
# precisionRate_T: 0.824242825899662
# recallRate_T: 0.6441238010399619
# F_T: 0.7231360509805974

# %%
recallTotal_ti = 0
precisionTotal_ti = 0
correctTotal_ti = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti':
        recallTotal_ti += 1

    if pair[2] == 'ti':
        precisionTotal_ti += 1

    if pair[1] == pair[2] and pair[1]== 'ti':
        correctTotal_ti += 1  

precisionRate_ti = 1.0 * correctTotal_ti / precisionTotal_ti
recallRate_ti = 1.0 * correctTotal_ti / recallTotal_ti
F_ti = 2 / (1/precisionRate_ti + 1/recallRate_ti)
  
'''
    仅统计ti
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_ti:', precisionRate_ti)  
print('recallRate_ti:', recallRate_ti)        
print('F_ti:', F_ti)
# Out:
# precisionRate_ti: 0.8619612411309965
# recallRate_ti: 0.8729154378250844
# F_ti: 0.8674037564939391

# %%
'''
    ti有的能预测出来，而给的数据没有标注出来，
    有的给的数据标出来的，但是预测不出来，看一下二者比例是多少
'''
pred_wrong = 0
pred_right = 0
pred_per = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti' and pair[2] != "ti":
        pred_wrong += 1

    if pair[1] != 'ti' and pair[2] == "ti":
        pred_right += 1

    if pair[1] == pair[2] == 'ti':
        pred_per += 1  

pred_wrong_rate = 1.0 * pred_wrong / ( pred_wrong + pred_right + pred_per )
pred_right_rate = 1.0 * pred_right / ( pred_wrong + pred_right + pred_per )

print('pred_wrong_rate:', pred_wrong_rate)  
print('pred_right_rate:', pred_right_rate)
# Out:
# pred_wrong_rate: 0.11149792999623635
# pred_right_rate: 0.12264772299585999

# %%
recallTotal_nr = 0
precisionTotal_nr = 0
correctTotal_nr = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'nr':
        recallTotal_nr += 1

    if pair[2] == 'nr':
        precisionTotal_nr += 1

    if pair[1] == pair[2] and pair[1]== 'nr':
        correctTotal_nr += 1  

precisionRate_nr = 1.0 * correctTotal_nr / precisionTotal_nr
recallRate_nr = 1.0 * correctTotal_nr / recallTotal_nr
F_nr = 2 / (1/precisionRate_nr + 1/recallRate_nr)
  
'''
    仅统计nr
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_nr:', precisionRate_nr)  
print('recallRate_nr:', recallRate_nr)        
print('F_nr:', F_nr)
# Out:
# precisionRate_nr: 0.824242825899662
# recallRate_nr: 0.6441238010399619
# F_nr: 0.7231360509805974

# %%
recallTotal_nt = 0
precisionTotal_nt = 0
correctTotal_nt = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'nt':
        recallTotal_nt += 1

    if pair[2] == 'nt':
        precisionTotal_nt += 1

    if pair[1] == pair[2] and pair[1]== 'nt':
        correctTotal_nt += 1  
        
precisionRate_nt = 1.0 * correctTotal_nt / precisionTotal_nt
recallRate_nt = 1.0 * correctTotal_nt / recallTotal_nt
F_nt = 2 / (1/precisionRate_nt + 1/recallRate_nt)

'''
    仅统计nt
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_nt:', precisionRate_nt)  
print('recallRate_nt:', recallRate_nt)        
print('F_nt:', F_nt)
# Out:
# precisionRate_nt: 0.8161448428146578
# recallRate_nt: 0.6869738983761019
# F_nt: 0.7460091993314879

# %%
# with open("./result_2.txt", "r", encoding="utf-8") as input:
#     for line in input:
#         line = line.strip()
#         pair = line.split(" ")
#         if len(pair) == 3:
#             print("ok")
# #         word = pair[0]
# #         truePos = pair[1]
# #         predPos = pair[2]
# #         flag = 0
# #         if truePos == "o" and predPos == "ti":  # 没有预测出来的ti
# #             flag = 1
# #             print(word)

# %% [markdown]
# ### result2.txt
# #### 结果来自trainData1Exp.txt，（0.txt -- 3878.txt）的训练，-f 8
# #### testData1Exp.txt，（38779.txt -- 42471.txt）的测试，
# #### 其中训练集取决于百度的分词结果，上传的分词库为1603行（去掉“测试”，“编辑”，“销售”）的title分词库
# #### 测试取决于百度的分词结果，上传的分词库为1405行（最初版）的title分词库

# %%
new_result = open('./result_2_NewFormat.txt','w',encoding='utf-8')
output = open('./result_2.txt','r',encoding='utf-8')
pairList = []
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        if "\t" in line:
            line = line.split("\t")
            tmp_1 = line
        else:
            pair = tmp_1[0] + " " + tmp_1[1] + " " +line
            new_result.write(tmp_1[0] + " " + tmp_1[1] + " " + line + "\r\n")
            pairList.append(pair)
output.close()
new_result.close()

# %%
print(len(pairList))
# Out:
# 5362114

# %%
recallTotal_T = 0
precisionTotal_T = 0
correctTotal_T = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == ('nr' or 'nt' or 'ti'):
        recallTotal_T += 1

    if pair[2] == ('nr' or 'nt' or 'ti'):
        precisionTotal_T += 1

    if pair[1] == pair[2] and pair[1]==('nr' or 'nt' or 'ti'):
        correctTotal_T += 1  
            
precisionRate_T = 1.0 * correctTotal_T / precisionTotal_T
recallRate_T = 1.0 * correctTotal_T / recallTotal_T
F_T = 2 / (1/precisionRate_T + 1/recallRate_T)

'''
    nr nt ti总的加一起
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_T:', precisionRate_T)   # 0.832209758148746
print('recallRate_T:', recallRate_T)         # 0.6355057902260156
print('F_T:',F_T)                            # 0.7206765923707164
# Out:
# precisionRate_T: 0.832209758148746
# recallRate_T: 0.6355057902260156
# F_T: 0.7206765923707164

# %%
recallTotal_ti = 0
precisionTotal_ti = 0
correctTotal_ti = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti':
        recallTotal_ti += 1

    if pair[2] == 'ti':
        precisionTotal_ti += 1

    if pair[1] == pair[2] and pair[1]== 'ti':
        correctTotal_ti += 1  

precisionRate_ti = 1.0 * correctTotal_ti / precisionTotal_ti
recallRate_ti = 1.0 * correctTotal_ti / recallTotal_ti
F_ti = 2 / (1/precisionRate_ti + 1/recallRate_ti)
  
'''
    仅统计ti
    训练集和测试集都直接按照百度API分词的结果来预测，人工修改了上传的分词库。
'''
print('precisionRate_ti:', precisionRate_ti)  
print('recallRate_ti:', recallRate_ti)        
print('F_ti:', F_ti)
# Out:
# precisionRate_ti: 0.750511591399658
# recallRate_ti: 0.7178132875757414
# F_ti: 0.7337983582519083

# %%
'''
    ti有的能预测出来，而给的数据没有标注出来，
    有的给的数据标出来的，但是预测不出来，看一下二者比例是多少
'''
pred_wrong = 0
pred_right = 0
pred_per = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti' and pair[2] != "ti":
        pred_wrong += 1

    if pair[1] != 'ti' and pair[2] == "ti":
        pred_right += 1

    if pair[1] == pair[2] == 'ti':
        pred_per += 1  

pred_wrong_rate = 1.0 * pred_wrong / ( pred_wrong + pred_right + pred_per )
pred_right_rate = 1.0 * pred_right / ( pred_wrong + pred_right + pred_per )

print('pred_wrong_rate:', pred_wrong_rate)  
print('pred_right_rate:', pred_right_rate)
# Out:
# pred_wrong_rate: 0.22782371531235118
# pred_right_rate: 0.19264903242564613

# %% [markdown]
# ### result3.txt
# #### 结果来自trainData1Exp.txt，（0.txt -- 3878.txt）的训练，-f 8
# #### testData1Exp.txt，（38779.txt -- 42471.txt）的测试，
# #### 其中训练集取决于百度的分词结果，上传的分词库为1603行（去掉“测试”，“编辑”，“销售”）的title分词库
# #### 测试取决于百度的分词结果，上传的分词库为1602行（去掉“测试”，“编辑”，“销售”，“UI”）的title分词库

# %%
'''
    这次写出来的结果，三列数据写成了两行，第一行是 word \t truePos，第二行是predictedPos。
    
    不知为啥格式变了。
'''
new_result = open('./result_3_NewFormat.txt','w',encoding='utf-8')
output = open('./result_3.txt','r',encoding='utf-8')
pairList = []
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        if "\t" in line:
            line = line.split("\t")
            tmp_1 = line
        else:
            pair = tmp_1[0] + " " + tmp_1[1] + " " +line
            new_result.write(tmp_1[0] + " " + tmp_1[1] + " " + line + "\r\n")
            pairList.append(pair)
output.close()
new_result.close()

# %%
recallTotal_T = 0
precisionTotal_T = 0
correctTotal_T = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == ('nr' or 'nt' or 'ti'):
        recallTotal_T += 1

    if pair[2] == ('nr' or 'nt' or 'ti'):
        precisionTotal_T += 1

    if pair[1] == pair[2] and pair[1]==('nr' or 'nt' or 'ti'):
        correctTotal_T += 1  
            
precisionRate_T = 1.0 * correctTotal_T / precisionTotal_T
recallRate_T = 1.0 * correctTotal_T / recallTotal_T
F_T = 2 / (1/precisionRate_T + 1/recallRate_T)

'''
    nr nt ti总的加一起
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_T:', precisionRate_T)  # 0.824242825899662
print('recallRate_T:', recallRate_T)        # 0.6441238010399619
print('F_T:',F_T)                          # 0.7231360509805974
# Out:
# precisionRate_T: 0.8320944112859469
# recallRate_T: 0.6355498456246503
# F_T: 0.7206616619086221

# %%
recallTotal_ti = 0
precisionTotal_ti = 0
correctTotal_ti = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti':
        recallTotal_ti += 1

    if pair[2] == 'ti':
        precisionTotal_ti += 1

    if pair[1] == pair[2] and pair[1]== 'ti':
        correctTotal_ti += 1  

precisionRate_ti = 1.0 * correctTotal_ti / precisionTotal_ti
recallRate_ti = 1.0 * correctTotal_ti / recallTotal_ti
F_ti = 2 / (1/precisionRate_ti + 1/recallRate_ti)
  
'''
    仅统计ti
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_ti:', precisionRate_ti)  
print('recallRate_ti:', recallRate_ti)        
print('F_ti:', F_ti)
# Out:
# precisionRate_ti: 0.8644842772588291
# recallRate_ti: 0.8779556720414791
# F_ti: 0.8711678986869444

# %%
'''
    ti有的能预测出来，而给的数据没有标注出来，
    有的给的数据标出来的，但是预测不出来，看一下二者比例是多少
'''
pred_wrong = 0
pred_right = 0
pred_per = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti' and pair[2] != "ti":
        pred_wrong += 1

    if pair[1] == 'o' and pair[2] == "ti":
        pred_right += 1

    if pair[1] == pair[2] == 'ti':
        pred_per += 1  

pred_wrong_rate = 1.0 * pred_wrong / ( pred_wrong + pred_right + pred_per )
pred_right_rate = 1.0 * pred_right / ( pred_wrong + pred_right + pred_per )

print('ti_pred_wrong_rate:', pred_wrong_rate)  
print('ti_pred_right_rate:', pred_right_rate)
# Out:
# ti_pred_wrong_rate: 0.10866752910737387
# ti_pred_right_rate: 0.10960606752403419

# %%
'''
    ti有的能预测出来，而给的数据没有标注出来，
    有的给的数据标出来的，但是预测不出来，看一下二者比例是多少
'''
pred_wrong = 0
pred_right = 0
pred_per = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'nr' and pair[2] == "o":
        pred_wrong += 1

    if pair[1] != 'nr' and pair[2] == "nr":
        pred_right += 1

    if pair[1] == pair[2] == 'nr':
        pred_per += 1  

nr_pred_wrong_rate = 1.0 * pred_wrong / ( pred_wrong + pred_right + pred_per )
nr_pred_right_rate = 1.0 * pred_right / ( pred_wrong + pred_right + pred_per )

print('nr_pred_wrong_rate:', pred_wrong_rate)  
print('nr_pred_right_rate:', pred_right_rate)
# Out:
# nr_pred_wrong_rate: 0.10866752910737387
# nr_pred_right_rate: 0.10960606752403419

# %% [markdown]
# ### result4.txt
# #### 结果来自RESULT.txt的训练，-f 8，是三列的，
# #### trainDataExp_v2.txt的测试，
# #### 其中训练集取决于百度的分词结果，上传的分词库为1619行的title分词库
# #### 测试取决于百度的分词结果，上传的分词库为1619行的title分词库

# %%
'''
    这次写出来的结果，三列数据写成了两行，第一行是 word \t truePos，第二行是predictedPos。
    
    不知为啥格式变了。
'''
new_result = open('./result_4_NewFormat.txt','w',encoding='utf-8')
output = open('./result_4.txt','r',encoding='utf-8')
pairList = []
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        if "\t" in line:
            line = line.split("\t")
            tmp_1 = line
        else:
            pair = tmp_1[0] + " " + tmp_1[1] + " " +line
            new_result.write(tmp_1[0] + " " + tmp_1[1] + " " + line + "\r\n")
            pairList.append(pair)
output.close()
new_result.close()

# %%
recallTotal_T = 0
precisionTotal_T = 0
correctTotal_T = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == ('nr' or 'nt' or 'ti'):
        recallTotal_T += 1

    if pair[2] == ('nr' or 'nt' or 'ti'):
        precisionTotal_T += 1

    if pair[1] == pair[2] and pair[1]==('nr' or 'nt' or 'ti'):
        correctTotal_T += 1  
            
precisionRate_T = 1.0 * correctTotal_T / precisionTotal_T
recallRate_T = 1.0 * correctTotal_T / recallTotal_T
F_T = 2 / (1/precisionRate_T + 1/recallRate_T)

'''
    nr nt ti总的加一起
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_T:', precisionRate_T)  # 0.824242825899662
print('recallRate_T:', recallRate_T)        # 0.6441238010399619
print('F_T:',F_T)                          # 0.7231360509805974
# Out:
# precisionRate_T: 0.858277870832901
# recallRate_T: 0.5336688233884496
# F_T: 0.6581231068248078

# %%
recallTotal_ti = 0
precisionTotal_ti = 0
correctTotal_ti = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti':
        recallTotal_ti += 1

    if pair[2] == 'ti':
        precisionTotal_ti += 1

    if pair[1] == pair[2] and pair[1]== 'ti':
        correctTotal_ti += 1  

precisionRate_ti = 1.0 * correctTotal_ti / precisionTotal_ti
recallRate_ti = 1.0 * correctTotal_ti / recallTotal_ti
F_ti = 2 / (1/precisionRate_ti + 1/recallRate_ti)
  
'''
    仅统计ti
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_ti:', precisionRate_ti)  
print('recallRate_ti:', recallRate_ti)        
print('F_ti:', F_ti)
# Out:
# precisionRate_ti: 0.8525220009864749
# recallRate_ti: 0.8484034308153353
# F_ti: 0.8504577296093436

# %% [markdown]
# ### result5.txt
# #### 结果来自RESULT_from_testData1.txt的训练，-f 8，改成两列
# #### trainData1Exp_v2.txt的测试，最后形成一个RESULT_from_trainData1.txt
# #### 其中训练集取决于百度的分词结果，上传的分词库为1619行的title分词库
# #### 测试取决于百度的分词结果，上传的分词库为1619行的title分词库

# %%
'''
    这次写出来的结果，三列数据写成了两行，第一行是 word \t truePos，第二行是predictedPos。
    
    不知为啥格式变了。
'''
new_result = open('./result_5_NewFormat.txt','w',encoding='utf-8')
output = open('./result_5.txt','r',encoding='utf-8')
pairList = []
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        if "\t" in line:
            line = line.split("\t")
            tmp_1 = line
        else:
            pair = tmp_1[0] + " " + tmp_1[1] + " " +line
            new_result.write(tmp_1[0] + " " + tmp_1[1] + " " + line + "\r\n")
            pairList.append(pair)
output.close()
new_result.close()

# %%
recallTotal_T = 0
precisionTotal_T = 0
correctTotal_T = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == ('nr' or 'nt' or 'ti'):
        recallTotal_T += 1

    if pair[2] == ('nr' or 'nt' or 'ti'):
        precisionTotal_T += 1

    if pair[1] == pair[2] and pair[1]==('nr' or 'nt' or 'ti'):
        correctTotal_T += 1  
            
precisionRate_T = 1.0 * correctTotal_T / precisionTotal_T
recallRate_T = 1.0 * correctTotal_T / recallTotal_T
F_T = 2 / (1/precisionRate_T + 1/recallRate_T)

'''
    nr nt ti总的加一起
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_T:', precisionRate_T)  # 0.824242825899662
print('recallRate_T:', recallRate_T)        # 0.6441238010399619
print('F_T:',F_T)
# Out:
# precisionRate_T: 0.8276275207591933
# recallRate_T: 0.6434948626662486
# F_T: 0.7240377331077925

# %%
recallTotal_ti = 0
precisionTotal_ti = 0
correctTotal_ti = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti':
        recallTotal_ti += 1

    if pair[2] == 'ti':
        precisionTotal_ti += 1

    if pair[1] == pair[2] and pair[1]== 'ti':
        correctTotal_ti += 1  

precisionRate_ti = 1.0 * correctTotal_ti / precisionTotal_ti
recallRate_ti = 1.0 * correctTotal_ti / recallTotal_ti
F_ti = 2 / (1/precisionRate_ti + 1/recallRate_ti)
  
'''
    仅统计ti
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_ti:', precisionRate_ti)  
print('recallRate_ti:', recallRate_ti)        
print('F_ti:', F_ti)
# Out:
# precisionRate_ti: 0.8385076963214193
# recallRate_ti: 0.9160016582029226
# F_ti: 0.8755432831015739

# %% [markdown]
# ### result6.txt
# #### 结果来自RESULT_from_trainData1.txt的训练，-f 8，改成两列
# #### trainData2Exp.txt的测试，
# #### 测试取决于百度的分词结果，上传的分词库为1722行的title分词库

# %%
'''
    这次写出来的结果，三列数据写成了两行，第一行是 word \t truePos，第二行是predictedPos。
    
    不知为啥格式变了。
'''
new_result = open('./result_6_NewFormat.txt','w',encoding='utf-8')
output = open('./result_6.txt','r',encoding='utf-8')
pairList = []
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        if "\t" in line:
            line = line.split("\t")
            tmp_1 = line
        else:
            pair = tmp_1[0] + " " + tmp_1[1] + " " +line
            new_result.write(tmp_1[0] + " " + tmp_1[1] + " " + line + "\r\n")
            pairList.append(pair)
output.close()
new_result.close()

# %%
recallTotal_ti = 0
precisionTotal_ti = 0
correctTotal_ti = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti':
        recallTotal_ti += 1

    if pair[2] == 'ti':
        precisionTotal_ti += 1

    if pair[1] == pair[2] and pair[1]== 'ti':
        correctTotal_ti += 1  

precisionRate_ti = 1.0 * correctTotal_ti / precisionTotal_ti
recallRate_ti = 1.0 * correctTotal_ti / recallTotal_ti
F_ti = 2 / (1/precisionRate_ti + 1/recallRate_ti)
  
'''
    仅统计ti
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_ti:', precisionRate_ti)  
print('recallRate_ti:', recallRate_ti)        
print('F_ti:', F_ti)
# Out:
# precisionRate_ti: 0.8117737089734142
# recallRate_ti: 0.9193362008088849
# F_ti: 0.8622132578722379

# %%
'''
    这次写出来的结果，三列数据写成了两行，第一行是 word \t truePos，第二行是predictedPos。
    
    不知为啥格式变了。
'''
new_result = open('./result_7_NewFormat.txt','w',encoding='utf-8')
output = open('./result_7.txt','r',encoding='utf-8')
pairList = []
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        if "\t" in line:
            line = line.split("\t")
            tmp_1 = line
        else:
            pair = tmp_1[0] + " " + tmp_1[1] + " " +line
            new_result.write(tmp_1[0] + " " + tmp_1[1] + " " + line + "\r\n")
            pairList.append(pair)
output.close()
new_result.close()

# %%
recallTotal_ti = 0
precisionTotal_ti = 0
correctTotal_ti = 0
# for sent in result:
for pair in pairList:
    pair = pair.split(" ")
    if pair[1] == 'ti':
        recallTotal_ti += 1

    if pair[2] == 'ti':
        precisionTotal_ti += 1

    if pair[1] == pair[2] and pair[1]== 'ti':
        correctTotal_ti += 1  

precisionRate_ti = 1.0 * correctTotal_ti / precisionTotal_ti
recallRate_ti = 1.0 * correctTotal_ti / recallTotal_ti
F_ti = 2 / (1/precisionRate_ti + 1/recallRate_ti)
  
'''
    仅统计ti
    训练集和测试集都直接按照百度API分词的结果来预测，没有人工修改。
'''
print('precisionRate_ti:', precisionRate_ti)  
print('recallRate_ti:', recallRate_ti)        
print('F_ti:', F_ti)
# Out:
# precisionRate_ti: 0.8468444042777526
# recallRate_ti: 0.9023239391410413
# F_ti: 0.8737043310696359

# %%
'''
    从 result_*_NewFormat.txt 转成 RESULT_from_*.txt
'''
new_result = open('./RESULT_from_trainData3.txt','w',encoding='utf-8')
output = open('./result_8_NewFormat.txt','r',encoding='utf-8')
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        pair = line.split(" ")
        word = pair[0]
        pos1 = pair[1]
        pos2 = pair[2]
        if pos1 == "o" and pos2 == "ti":
            new_result.write(word + " " + pos2 + "\r\n")
        else:
            new_result.write(word + " " + pos1 + "\r\n")
output.close()
new_result.close()

# %%
'''
    这次写出来的结果，三列数据写成了两行，第一行是 word \t truePos，第二行是predictedPos。
    
    不知为啥格式变了。
'''
new_result = open('./result_8_NewFormat.txt','w',encoding='utf-8')
output = open('./result_8.txt','r',encoding='utf-8')
pairList = []
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        if "\t" in line:
            line = line.split("\t")
            tmp_1 = line
        else:
            pair = tmp_1[0] + " " + tmp_1[1] + " " +line
            new_result.write(tmp_1[0] + " " + tmp_1[1] + " " + line + "\r\n")
            pairList.append(pair)
output.close()
new_result.close()

# %%
# output1 = open('./RESULT_from_trainData3.txt','r',encoding='utf-8')
output2 = open('./RESULT_from_trainData2.txt','r',encoding='utf-8')
output3 = open('./RESULT_from_trainData1.txt','r',encoding='utf-8')
# output4 = open('./RESULT_from_testData1.txt','r',encoding='utf-8')
# output5 = open('./RESULT_from_trainData4.txt','r',encoding='utf-8')
output = open('./Corpus_2.txt','w',encoding='utf-8')

# for line in output1:
#     line = line.strip()
#     if line:
#         pair = line.split(" ")
#         word = pair[0]
#         pos = pair[1]
#         output.write(word + " " + pos + "\r\n")
        
for line in output2:
    line = line.strip()
    if line:
        pair = line.split(" ")
        word = pair[0]
        pos = pair[1]
        output.write(word + " " + pos + "\r\n")   
        
for line in output3:
    line = line.strip()
    if line:
        pair = line.split(" ")
        word = pair[0]
        pos = pair[1]
        output.write(word + " " + pos + "\r\n")

# for line in output4:
#     line = line.strip()
#     if line:
#         pair = line.split(" ")
#         word = pair[0]
#         pos = pair[1]
#         output.write(word + " " + pos + "\r\n")
        
# for line in output5:
#     line = line.strip()
#     if line:
#         pair = line.split(" ")
#         word = pair[0]
#         pos = pair[1]
#         output.write(word + " " + pos + "\r\n")
        
output.close()
# output1.close()
output2.close()
output3.close()
# output4.close()
# output5.close()

# %%
'''
    这次写出来的结果，三列数据写成了两行，第一行是 word \t truePos，第二行是predictedPos。
    
    不知为啥格式变了。
'''
new_result = open('./result_9_NewFormat.txt','w',encoding='utf-8')
output = open('./result_9.txt','r',encoding='utf-8')
pairList = []
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        if "\t" in line:
            line = line.split("\t")
            tmp_1 = line
        else:
            pair = tmp_1[0] + " " + tmp_1[1] + " " +line
            new_result.write(tmp_1[0] + " " + tmp_1[1] + " " + line + "\r\n")
            pairList.append(pair)
output.close()
new_result.close()

# %%
'''
    result_*_NewFormat.txt中筛选出 truePos为"o"，predPos为"ti"的“新预测出来的title”
    而且踢掉已经在new_title_gbk.txt中已经存在的title
'''

result = open('./result_9_NewFormat.txt','r',encoding='utf-8')
title = open('./new_title_gbk.txt','r',encoding='gbk')
# new_title = open('./add_new_title.txt','w',encoding='utf-8')

title_list = []

for line in title:
    line = line.strip()
    title_list.append(line)

pair_list = []

for line in result:
    line = line.strip()
    pair = line.split(" ")
    word = pair[0]
    pos1 = pair[1]
    pos2 = pair[2]
    pair_list.append([word, pos1, pos2])
# print(pair_list[0][1])        

result.close()
title.close()
# new_title.close()

# %%
cut = ""
tmp_cut = ""
count = 1
gap = 1
useless_title = ["创始人", "股东", "董事", "开发", "医生", "编辑", "记者", "合伙人",
                "销售", "专家", "律师", "教师", "老师", "教学", "教授", "教练", "博士",
                "演员", "工程师", "主持人", "委员", "理事"]
for i in range(len(pair_list)):
    if pair_list[i][0] in tmp_cut and pair_list[i-1][0] in tmp_cut:
        count = count + 1
        continue
    if pair_list[i][1] == "o" and pair_list[i][2] == "ti":
        cut = pair_list[i][0]
        count = count + 1
        for j in range(i+1, i+20):
            if pair_list[j][1] == "o" and pair_list[j][2] == "ti":
                cut = cut + pair_list[j][0]
                count = count +1
                gap  = gap + 1
#             for l in range(j+1, j+10):
#                 if pair_list[l][1] == "ti" and pair_list[l][2] == "ti":
#                     cut = cut + pair_list[l][0]
            else:
                if cut not in title_list and cut not in useless_title:
                    print(str(count-gap) + " " + cut)
                tmp_cut = cut
                cut = ""
                break
    else:
        count = count + 1
        continue
# Out:
# 12081 监事
# 25957 因裁员
# 26790 助理
# 49632 成员总顾问
# 49657 :
# 52596 博士及博士
# 61601 设计师
# 64370 校长
# 65138 校长
# 65449 校长
# 69773 主管
# 69994 主管
# 83527 或
# 88253 家长委员
# 88622 主任老师
# 114704 委书记
# 141699 人
# 149081 带教老师
# 151161 校长
# 156484 副船长
# 165115 及
# 170254 实行
# 172085 兼
# 173274 局
# 177322 主创
# 181281 导师
# 181683 教学指导委员会
# 187369 唱者
# 195024 高级业务
# 199675 演
# 199691 主演
# 202800 助理工程师
# 202822 队长
# 214877 法官
# 233659 专长
# 241482 班长
# 245241 顾问老师
# 245690 顾问老师
# 249787 教堂
# 252495 顾问老师
# 252521 顾问
# 252637 顾问老师
# 270959 教生
# 273925 校长
# 284789 全员销售
# 291546 联合开发
# 297495 销书
# 297665 校长
# 307593 处
# 307607 处
# 307814 所长
# 308954 教授级
# 309967 总长
# 311879 人
# 313589 主理
# 313726 主理
# 318923 医师
# 319125 药师
# 332939 恩师
# 342276 队员
# 353681 庄
# 353720 庄
# 353921 庄
# 354270 庄
# 354310 庄
# 354401 庄
# 354656 庄经理
# 365781 教堂
# 366145 主教堂
# 369484 校长
# 378882 员主持人
# 386098 委员长
# 386953 术师
# 387664 魔术顾问
# 387679 魔术顾问
# 418278 会员
# 431319 主人
# 431783 合师
# 439327 创始人兼首席执行
# 439659 会员
# 441246 教主
# ...

# %%
'''
    从 result_*_NewFormat.txt 转成 RESULT_from_*.txt
'''
new_result = open('./RESULT_from_trainData3.txt','w',encoding='utf-8')
output = open('./result_9_NewFormat.txt','r',encoding='utf-8')
for line in output:
    line = line.encode('utf-8').decode('utf-8-sig').strip()
    if line:
        pair = line.split(" ")
        word = pair[0]
        pos1 = pair[1]
        pos2 = pair[2]
        if pos1 == "o" and pos2 == "ti":
            new_result.write(word + " " + pos2 + "\r\n")
        else:
            new_result.write(word + " " + pos1 + "\r\n")
output.close()
new_result.close()

# %%
test1 = open('./RESULT_from_testData1.txt','r',encoding='utf-8')
train1 = open('./Corpus_3.txt','r',encoding='utf-8')

test1_Sent = []
train1_Sent = []

for line in test1:
    line = line.strip()
    pair = line.split(" ")
    word = pair[0]
    pos = pair[1]
    test1_Sent.append([word,pos])
# print(len(test1_Sent))
j = 0
for i in range(len(test1_Sent)):
    if test1_Sent[i][0] == 'CEO':
        if test1_Sent[i-1]:
            if test1_Sent[i-1][0] == "兼":
                j += 1
print(j)
# Out:
# 109

# %%
for line in train1:
    line = line.strip()
    pair = line.split(" ")
    if pair[0] and pair[1]:
        word = pair[0]
        pos = pair[1]
        train1_Sent.append([word,pos])
# print(len(test1_Sent))
k = 0
for i in range(len(train1_Sent)):
    if train1_Sent[i][0] == 'CEO':
        if train1_Sent[i-1]:
            if train1_Sent[i-1][0] == "兼":
                k += 1
print(k)
# Out:
# 396
