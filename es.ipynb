# %% [markdown]
# ### 从es中读取数据，将数据写进文件，再调用百度接口进行分词。

# %% [markdown]
# ## es连接

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import re
import sys
import time
from datetime import datetime
import random

es = Elasticsearch('http://ip:port')

# %% [markdown]
# ## query设置-----全量读取

# %%
query = {
  "query": {
    "match_all": {}
  },
  "_source": {
    "includes": [
      "url",
      "title",
      "content"
    ]
  }
}

# %%
# 读取全部平台的数据（包括36kr(36kr_bl),百度(baidu_bl)，微信公众号(wechat_bl)，今日头条(toutiao_bl)）
doc_index_total = '*_bl'
doc_type_total = 'news'
dataGen_total = helpers.scan(es, 
                   query=query, 
                   index=doc_index_total, 
                   doc_type=doc_type_total, 
                   scroll="10m", 
                   raise_on_error=True, 
                   preserve_order=True,
                   timeout='10m')
data_total = list(dataGen_total)
# len(data_total) # 56026

# %%
# 读取36kr数据
doc_index = '36kr_bl'
doc_type = 'news'
dataGen = helpers.scan(es, 
                   query=query, 
                   index=doc_index, 
                   doc_type=doc_type, 
                   scroll="10m", 
                   raise_on_error=True, 
                   preserve_order=True,
                   timeout='10m')
data = list(dataGen)
# len(data) # 918

# %%
# data[0]['_source']['content']

# %% [markdown]
# ## 解析html，返回句子

# %%
# 拆分为句子
def sentencesMaker(html):

    import justext
    paragraphs = justext.justext(html, [])

    cache_sentences = ''
    sentences = []

    for p in paragraphs:
        sent = p.text.strip().replace('\xa0', '').replace('\u3000', '')
        sent = sent.encode('gb2312', 'ignore').decode('gb2312').encode('gbk', 'ignore').decode('gbk')
        if not sent:
            continue

        # 可能是含有名字，需要进一步处理
        if len(cache_sentences) < 5:
            cache_sentences += ' ' + sent

        else:
            sentences.append(cache_sentences.strip())
            cache_sentences = sent

    if not not cache_sentences:
        sentences.append(cache_sentences.strip())

    return sentences

# %%
# print(type(data_total[0]))

# %%
# print("\n".join((sentencesMaker(data[0]['_source']['content']))))

# %% [markdown]
# ## 从es中读取的所有数据写入到一个txt中

# %%
# 写36kr数据，剔除content=null的数据

dataset = open('data_36kr.txt', 'w', encoding='utf-8')
i = 1
for item in data:
    source = item['_source']
    title = source['title']
    url = source['url']
    content = "".join(sentencesMaker(source['content']))
    if content:
        dataset.write('sentence%s:' % str(i) + '\r\n')
        dataset.write('url:'+' '+url+'\r\n')
        dataset.write('title:'+' '+title+'\r\n')
        dataset.write('content:'+' '+str(content)+'\r\n')
        dataset.write('\n')
        i += 1
    else:
        dataset.write('\n')
dataset.close()

# %%
# 写所有数据，剔除content=null的数据
# 共55397行，写入了一个.txt文件中，dataTotal.txt
# 格式为 sentence1：
#       url:
#       title:
#       content:
# 不去除标识(url\title\content)

dataset1 = open('dataTotal.txt', 'w', encoding='utf-8')
i = 1    
for item in data_total:
    try:
        source = item['_source']
        title = source.get('title',None) # 返回指定键的值，如果值不在字典中返回默认值None。
        html = source.get('content', None)
        if html:
            html = html.strip()
        if not html or not title: # 如果html或title有一个为空，跳出本次循环
            continue
        if not isinstance(html, str): # 判断html是否是str类型，如果不是，跳出本次循环
            continue
        url = source['url']
        content = "".join(sentencesMaker(html)).strip()
        if content:
            dataset1.write('sentence%s:' % str(i) + '\r\n')
            dataset1.write('url:'+' '+url+'\r\n')
            dataset1.write('title:'+' '+title+'\r\n')
            dataset1.write('content:'+' '+str(content)+'\r\n')
            dataset1.write('\n')
            i += 1
        else:
            dataset1.write('\n')
    except Exception as e:
        print(item)
        raise e
dataset1.close()

# %%
# 写所有数据，剔除content=null的数据
# 共55397行，写入了一个.txt文件中，dataTotal2.txt
# 格式为 url:
#       title+content:
# 去掉标识(url、title+content)

dataset2 = open('dataTotal2.txt', 'w', encoding='utf-8')
# i = 1    
for item in data_total:
    try:
        source = item['_source']
        title = source.get('title',None) # 返回指定键的值，如果值不在字典中返回默认值None。
        html = source.get('content', None)
        if html:
            html = html.strip()
        if not html or not title:
            continue
        if not isinstance(html, str): # 判断html是否是str类型
            continue
        url = source['url']
        content = "".join(sentencesMaker(html)).strip()
        if content:
#             dataset1.write('sentence%s:' % str(i) + '\r\n')
            dataset2.write(url+'\r\n')
            dataset2.write(title+'。'+content+'\r\n')
#             dataset2.write('content:'+' '+str(content)+'\r\n')
            dataset2.write('\n')
#             i += 1
        else:
            dataset2.write('\n')
    except Exception as e:
        print(item)
        raise e
dataset2.close()

# %% [markdown]
# ## 将获取的每篇数据写入一个.txt文件中

# %%
# 按每三行写一篇.txt，后来发现数据格式有点比较差，不能这么写。

# index = 0
# count = 0
# f_in = open("./data/%d.txt" % index, "w")
# with open("dataTotal2.txt", "r") as f_out:
#     for line in f_out:
#         count += 1
#         f_in.write(line)

#         # 读满3行之后，行计数置零，小文件序号加1，创建一个新的文件写信息
#         if count == 3:
#             f_in.close()
#             count = 0
#             index += 1
#             f_in = open("./data/%d.txt" % index, "w")

# %%
# 按遇到下一个sentence时，停止写文件，较准确

count = 0
index = 0
f_in = open("./data/%d.txt" % index, "w")
with open("dataTotal.txt", "r") as f_out:
    for line in f_out:
        line = line.strip()
        count += 1       
        if count > 1 and line.startswith("sentence"):
            f_in.close()
            count = 0
            index += 1
            f_in = open("./data/%d.txt" % index, "w")
        else:
            f_in.write(line+'\r\n')

# %%
# 查看文件目录下共写了多少个txt，查看每个txt的命名是否有误
import os
print(len(os.listdir("./data")))
# 文件目录下多了个.ipynb_checkpoints，要删除，否则会报错
# os.rmdir("./data/.ipynb_checkpoints")
print(os.listdir("./data")[:20])
# Out:
# 55399
# ['0.txt', '1.txt', '2.txt', '3.txt', '4.txt', '5.txt', '6.txt', '7.txt', '8.txt', '9.txt', '10.txt', '11.txt', '12.txt', '13.txt', '14.txt', '15.txt', '16.txt', '17.txt', '18.txt', '19.txt']

# %% [markdown]
# ## 百度api，句子拆分与合并

# %%
from aip import AipNlp

APP_ID = '11513666'
API_KEY = 'Tpw3HSxiWqPZbm5tqRRQDd6H'
SECRET_KEY = 'tOuMo5GNXEh6GyDVokSAkjMWVZFKAjHm'

client = AipNlp(APP_ID, API_KEY, SECRET_KEY)

# %%
# 改善QPS限制

import time
import sys
import re
SPLIT_LINE_MARKER = '！'
SPLIT_LINE_MARKER_SIZE = 3

# 拆分为句子
# def sentencesMaker(html):

#     import justext
#     paragraphs = justext.justext(html, [])

#     cache_sentences = ''
#     sentences = []


#     for p in paragraphs:
#         sent = p.text.strip().replace('\xa0', '').replace('\u3000', '')
#         sent = sent.encode('gb2312', 'ignore').decode('gb2312').encode('gbk', 'ignore').decode('gbk')
#         if not sent:
#             continue

#         # 可能是含有名字，需要进一步处理
#         if len(cache_sentences) < 5:
#             cache_sentences += ' ' + sent

#         else:
#             sentences.append(cache_sentences.strip())
#             cache_sentences = sent

#     if not not cache_sentences:
#         sentences.append(cache_sentences.strip())

#     return sentences

# 重新恢复句子
def restoreSentences(text, only_per=False):  # 长度不超过3700字节的句子
    restore_sentences = []
    isSucc = False
    if text is None:
        return restore_sentences, isSucc

    result = client.lexerCustom(text)

    items = result.get('items', [])
    items_size = len(items)

    tries_limit = 3
    tries_counter = 0
    
    while items_size == 0: # 分词结果为空
        if len(text) != 0: # 但句子长度不为空
            # 可能是qps限制
            time.sleep(1)
            result = client.lexerCustom(text)

            items = result.get('items', [])
            items_size = len(items)
            isSucc=True

        tries_counter += 1

        if tries_counter >= tries_limit: # 分词尝试大于等于4次之后仍失败
            print(f'error: 分词api请求失败多次！{text}')
#             print('error: 分词api请求失败多次!')
            return restore_sentences, isSucc

    restore_idx = 0

    last_restore_idx = 0
    has_per = False

    while restore_idx < items_size: # 对每个分词结果进行整理 
        # 分词不是拼接符"!!!"
        while restore_idx < items_size and items[restore_idx]['item'] != SPLIT_LINE_MARKER:
            item = items[restore_idx] # 先把第一个分词的结果(dict)赋值给item，item整理之后再直接赋给原items[]
            # TODO 剔除机构中的不合法字符
            format_pos = item['pos']
            
            # 对非ne标识的分词不做处理
            
            if item['ne'].startswith('ORG'): # 如果该分词的ne是ORG
                invalid_orgs = ['公司']
                item['item'] = item['item'].replace('&', '')
                if item['item'] in invalid_orgs:
                    format_pos = 'n' # 普通名词
                else:
                    format_pos = 'nt'  # 机构团体名

            elif item['ne'] == 'PER': # 如果该分词的ne是PER
                format_pos = 'nr' # 人名

            elif item['ne'] == 'TITLE': # 如果该分词的ne是TITLE（定制）
                format_pos = 'ti' # 职称

            elif item['ne'] == 'LOC': # 如果该分词的ne是LOC
                format_pos = 'ns'  # 地名

            elif item['ne'] == 'TIME': # 如果该分词的ne是TIME
                format_pos = 't' # 时间名词
                
                

            if format_pos == '': #如果pos为空，即是其他非上述的ne标识，将pos置为"xx"
                format_pos = 'xx'

            elif format_pos == 'nr':
                # 过滤先生或者女士之类的名称
                name = re.sub(r'((先生)|(小姐)|(阿姨)|(叔叔)|(女士)|(同志)|总)$', '', item['item'])

                if len(name) >= 2:
                    invalid_names = {
                        '区块链': 'n'
                    }

                    if name not in invalid_names:
                        has_per = True
                        item['item'] = name
                    else:
                        format_pos = invalid_names[name]

                else: # 剔除称谓之后的name长度如果小于2，就不是nr，设为n

                     format_pos = 'n'




            item['pos'] = format_pos # 处理之后的pos赋值给原分词的pos

            # 删除无用信息
            item.pop('basic_words')
            item.pop('formal')
            item.pop('byte_length')
            item.pop('byte_offset')
            item.pop('loc_details')
            item.pop('ne')
            item.pop('uri')

            items[restore_idx] = item # 处理之后的分词结果赋给原分词结果
            restore_idx += 1 # 继续下一个item

            
        # 若遇到了拼接符"!!!"或对所有非拼接符的分词结果处理完毕    
        if restore_idx + SPLIT_LINE_MARKER_SIZE - 1 < items_size: 
            needCut = True 
            for i in range(SPLIT_LINE_MARKER_SIZE - 1): 
                if items[restore_idx + i + 1]['item'] != SPLIT_LINE_MARKER:
                    needCut = False
                    break

            if needCut:
                ed = max(restore_idx, 0)

                sentence_items = items[last_restore_idx:ed] # 切句子，[0:restore_idx]
                if len(sentence_items) != 0 and (has_per or not only_per):
                    # print('per:', sentence_items)
                    restore_sentences.append(sentence_items)

                next_st = min(ed + SPLIT_LINE_MARKER_SIZE, items_size)
                last_restore_idx = next_st

                restore_idx += SPLIT_LINE_MARKER_SIZE
            else:
                restore_idx += 1

        else: # 句末最后一个拼接符
            ed = max(restore_idx, 0)
            sentence_items = items[last_restore_idx:ed]
            if len(sentence_items) != 0 and (has_per or not only_per):

                restore_sentences.append(sentence_items)

            restore_idx = items_size

        has_per = False

    # print(restore_sentences)
    return restore_sentences, isSucc


# 解析并标注HTML
def posHtml(sentences, only_per=False):
#     sentences = sentencesMaker(html) # 将带有html标签的段落整理成一个list,去除标签的文字段落。


    cut_str = '' 

    pos_sentences = []

    for sent in sentences:
        sent = sent.strip()
        if not sent:  # 若句子为空，跳出循环
            continue
        if not cut_str: # 若cut_str为空，即第一句之前，把第一句话赋值给tmp_str
            tmp_str = sent
        else: # 若cut_str里有句子，将后续句子拼接，以“!!!”作为拼接符，再赋值给tmp_str
            tmp_str = cut_str + SPLIT_LINE_MARKER * SPLIT_LINE_MARKER_SIZE + sent
        if sys.getsizeof(tmp_str) < 3700: # 拼接之后的句子小于3700字节
            cut_str = tmp_str # tmp_str赋值给cut_str，继续拼接sent
        else:
            try:
                if cut_str:
                    time.sleep(0.5) # 拼接之后的tmp_str若大于3700字节，取未拼接该sent之前的cut_str拿来分词
                    sents, issucc = restoreSentences(cut_str, only_per)
                    pos_sentences += sents
    #                 if not issucc:
    #                     print(html)

            except Exception as e:
                print(e)
                print('error: ', sent)

            cut_str = sent # 把刚才没有拼接成功的sent重新赋给cut_str


    if not not cut_str: # 最后一句sent
        time.sleep(0.5)
        try:
            if cut_str:
                time.sleep(0.5) # 拼接之后的tmp_str若大于3700字节，取未拼接该sent之前的cut_str拿来分词
                sents, issucc = restoreSentences(cut_str, only_per)
                pos_sentences += sents
#                 if not issucc:
#                     print(html)
        except Exception as e:
            print(e)
            print('error: ', sent)

    return pos_sentences

# %%
restoreSentences("这是一个测试的小句子")
# Out:
# ([[{'item': '这', 'pos': 'r'},
#    {'item': '是', 'pos': 'v'},
#    {'item': '一个', 'pos': 'm'},
#    {'item': '测试', 'pos': 'v'},
#    {'item': '的', 'pos': 'u'},
#    {'item': '小', 'pos': 'a'},
#    {'item': '句子', 'pos': 'n'}]],
#  False)

# %%
posHtml("这是一个测试的小句子")
# Out:
# [[{'item': '这', 'pos': 'r'}],
#  [{'item': '是', 'pos': 'v'}],
#  [{'item': '一', 'pos': 'm'}],
#  [{'item': '个', 'pos': 'q'}],
#  [{'item': '测', 'pos': 'v'}],
#  [{'item': '试', 'pos': 'v'}],
#  [{'item': '的', 'pos': 'u'}],
#  [{'item': '小', 'pos': 'a'}],
#  [{'item': '句', 'pos': 'n'}],
#  [{'item': '子', 'pos': 'n'}]]

# %% [markdown]
# ## 将./data数据7/3份划分训练集和测试集

# %%
# import os,shutil
            
# i = 0            
# ls = os.listdir("./data")
# try:
#     for line in ls:
#         filePath = os.path.join("./data", line)
#         if os.path.isfile(filePath):
#             if i < 38778:
#                 shutil.copy(filePath, "./trainData")
#                 i += 1
#             else:
#                 shutil.copy(filePath, "./testData")
#         else:
#             continue
# except Exception as e:
#     print(e)

# %%
list_c = [a for a in trainData if a in testData]
print(list_c)  # 训练集和测试集没有重复的文件
# Out:
# []

# %% [markdown]
# ## 批量读取训练集的分词结果

# %%
import os
import json
# import shutil
# shutil.rmtree("./data/.ipynb_checkpoints")
total_number = 0
# wrong_number = 0
log = open('log1.txt', 'w', encoding='utf-8')
f = open('corpus2.json', 'w', encoding="utf-8")
i = 0

caches = []
for file in os.listdir(r'./data'):
    domain = os.path.abspath(r'./data')
    file = os.path.join(domain, file) # 获取trainData下的所有文件
#     print(file)
    if i < 5:
        data = open(file, "r", encoding="utf-8")
        title = ''
        content = ''
        para = []
        for line in data:
            line = line.strip()
            if line.startswith("title"):
                title = line[6:]
            if line.startswith("content"):
                content = line[8:]
        text = title + content
        text = text.split("。")
        for line in text:
            para.append(line)
        f.write(json.dumps(posHtml(para),ensure_ascii=False,indent=2))
        print(i, '******************************************')
        i += 1
        caches.append(text)
        total_number += 1
    else:
        continue
print("total_number", total_number)
# Out:
# 0 ******************************************
# 1 ******************************************
# 2 ******************************************
# 3 ******************************************
# 4 ******************************************
# total_number 5

# %%
client.lexerCustom(caches[3])
# Out:
# {'log_id': 8378757205452365828,
#  'error_code': 282002,
#  'error_msg': 'input encoding error'}

# %% [markdown]
#  ## 将分词结果转成word pos形式，不剔除重复项。

# %%
item = []
pos = []
flag = 0
corpus = open("./corpus2.txt", "w", encoding="utf-8")
with open("./corpus2.json", "r") as json_result:
    for line in json_result:
        line = line.strip()
        if "[" in line:
            continue
        if "{" in line:
            continue
        if "}" in line:
            continue
        if "]" in line:
            continue
        if "item" in line:
            item.append(line.replace(",","").split(":")[1].split('"')[1])
        elif "pos" in line and flag ==0:
            pos.append(line.split(":")[1].split('"')[1])
    dic = zip(item, pos)
    for key, value in dic:
        corpus.write(key+ " "+value + '\n')
    corpus.close()

# %% [markdown]
# ## 将trainData分10次进行分词，转形式处理。
# ### es.py进行第1，3次处理；
# #### 其中第1次处理的结果，即报gbk编码问题保存在本地 D:\Google Download\编码错误的部分。
# #### 第2，3，...，10次处理的结果保存在控制台，暂未做处理。
# #### trainData中之所以会出现那么多带！！！没有分词的段落是因为当时让9份分词程序同时跑，同时访问百度的API接口，所以会出现这个现象，后面再测试的时候，就几乎没有这个问题了，所以代码中split("！！！")这一步其实没有作用。
# ### train1.py进行第2次处理；
# ### train3.py进行第4次处理；
# ### .....................
# ### train9.py进行第10次处理；

# %%
import os
import json
total_number = 0
f = open('trainData_111111.json', 'w', encoding="utf-8")
for file in os.listdir(r'./trainData'):
    number = int(file.split('.')[0]) 
    domain = os.path.abspath(r'./trainData')
    file = os.path.join(domain, file) 
    if 0 <= number <= 3878: 
        print(file)
        data = open(file, "r", encoding="utf-8")
        title = ''
        content = ''
        para = []
        for line in data:
            line = line.strip()
            try:
                if line.startswith("title"):
                    title = line[6:]
                if line.startswith("content"):
                    content = line[8:]
            except Exception as e:
                print(1)
                print(e)
        text = title + content
        text = text.split("。")
        for line in text:
            para.append(line)
        f.write(json.dumps(posHtml(para),ensure_ascii=False,indent=2))
#         caches.append(text)
        total_number += 1
    else:
        continue
print("total_number", total_number)
# Out:
# /home/lx/Projects/wjc/es/trainData/0.txt
# /home/lx/Projects/wjc/es/trainData/1.txt
# /home/lx/Projects/wjc/es/trainData/2.txt
# /home/lx/Projects/wjc/es/trainData/3.txt
# /home/lx/Projects/wjc/es/trainData/4.txt
# /home/lx/Projects/wjc/es/trainData/5.txt
# /home/lx/Projects/wjc/es/trainData/6.txt
# /home/lx/Projects/wjc/es/trainData/7.txt
# /home/lx/Projects/wjc/es/trainData/8.txt
# /home/lx/Projects/wjc/es/trainData/9.txt
# /home/lx/Projects/wjc/es/trainData/10.txt
# /home/lx/Projects/wjc/es/trainData/11.txt
# /home/lx/Projects/wjc/es/trainData/12.txt
# /home/lx/Projects/wjc/es/trainData/13.txt
# /home/lx/Projects/wjc/es/trainData/14.txt
# /home/lx/Projects/wjc/es/trainData/15.txt
# 'gbk' codec can't encode character '\u2022' in position 57: illegal multibyte sequence
# error:  我们希望这是我们的一个优势
# /home/lx/Projects/wjc/es/trainData/16.txt
# /home/lx/Projects/wjc/es/trainData/17.txt
# /home/lx/Projects/wjc/es/trainData/18.txt
# /home/lx/Projects/wjc/es/trainData/19.txt
# /home/lx/Projects/wjc/es/trainData/20.txt
# /home/lx/Projects/wjc/es/trainData/21.txt
# /home/lx/Projects/wjc/es/trainData/22.txt
# /home/lx/Projects/wjc/es/trainData/23.txt
# /home/lx/Projects/wjc/es/trainData/24.txt
# /home/lx/Projects/wjc/es/trainData/25.txt
# /home/lx/Projects/wjc/es/trainData/26.txt
# /home/lx/Projects/wjc/es/trainData/27.txt
# /home/lx/Projects/wjc/es/trainData/28.txt
# /home/lx/Projects/wjc/es/trainData/29.txt
# /home/lx/Projects/wjc/es/trainData/30.txt
# /home/lx/Projects/wjc/es/trainData/31.txt
# /home/lx/Projects/wjc/es/trainData/32.txt
# /home/lx/Projects/wjc/es/trainData/33.txt
# /home/lx/Projects/wjc/es/trainData/34.txt
# /home/lx/Projects/wjc/es/trainData/35.txt
# /home/lx/Projects/wjc/es/trainData/36.txt
# /home/lx/Projects/wjc/es/trainData/37.txt
# /home/lx/Projects/wjc/es/trainData/38.txt
# /home/lx/Projects/wjc/es/trainData/39.txt
# /home/lx/Projects/wjc/es/trainData/40.txt
# /home/lx/Projects/wjc/es/trainData/41.txt
# /home/lx/Projects/wjc/es/trainData/42.txt
# /home/lx/Projects/wjc/es/trainData/43.txt
# /home/lx/Projects/wjc/es/trainData/44.txt
# /home/lx/Projects/wjc/es/trainData/45.txt
# /home/lx/Projects/wjc/es/trainData/46.txt
# /home/lx/Projects/wjc/es/trainData/47.txt
# /home/lx/Projects/wjc/es/trainData/48.txt
# /home/lx/Projects/wjc/es/trainData/49.txt
# /home/lx/Projects/wjc/es/trainData/50.txt
# /home/lx/Projects/wjc/es/trainData/51.txt
# /home/lx/Projects/wjc/es/trainData/52.txt
# /home/lx/Projects/wjc/es/trainData/53.txt
# /home/lx/Projects/wjc/es/trainData/54.txt
# /home/lx/Projects/wjc/es/trainData/55.txt
# /home/lx/Projects/wjc/es/trainData/56.txt
# /home/lx/Projects/wjc/es/trainData/57.txt
# /home/lx/Projects/wjc/es/trainData/58.txt
# /home/lx/Projects/wjc/es/trainData/59.txt
# /home/lx/Projects/wjc/es/trainData/60.txt
# 'gbk' codec can't encode character '\xa0' in position 22: illegal multibyte sequence
# error:  氪空间总裁钟澍表示：“新商业时代，人们的工作方式和办公空间在不断进化，作为联合办公代表性企业，氪空间正在通过整合空间、人才和企业目标，有效的提升空间使用效率、降低成本、优化体验，并创造丰富机会推动企业业务成果，重构工作场景，为企业提供空间赋能
# /home/lx/Projects/wjc/es/trainData/61.txt
# /home/lx/Projects/wjc/es/trainData/62.txt
# /home/lx/Projects/wjc/es/trainData/63.txt
# /home/lx/Projects/wjc/es/trainData/64.txt
# /home/lx/Projects/wjc/es/trainData/65.txt
# /home/lx/Projects/wjc/es/trainData/66.txt
# /home/lx/Projects/wjc/es/trainData/67.txt
# /home/lx/Projects/wjc/es/trainData/68.txt
# /home/lx/Projects/wjc/es/trainData/69.txt
# /home/lx/Projects/wjc/es/trainData/70.txt
# /home/lx/Projects/wjc/es/trainData/71.txt
# /home/lx/Projects/wjc/es/trainData/72.txt
# /home/lx/Projects/wjc/es/trainData/73.txt
# /home/lx/Projects/wjc/es/trainData/74.txt
# /home/lx/Projects/wjc/es/trainData/75.txt
# /home/lx/Projects/wjc/es/trainData/76.txt
# /home/lx/Projects/wjc/es/trainData/77.txt
# /home/lx/Projects/wjc/es/trainData/78.txt
# /home/lx/Projects/wjc/es/trainData/79.txt
# /home/lx/Projects/wjc/es/trainData/80.txt
# /home/lx/Projects/wjc/es/trainData/81.txt
# /home/lx/Projects/wjc/es/trainData/82.txt
# /home/lx/Projects/wjc/es/trainData/83.txt
# /home/lx/Projects/wjc/es/trainData/84.txt
# /home/lx/Projects/wjc/es/trainData/85.txt
# 'gbk' codec can't encode character '\u200b' in position 10: illegal multibyte sequence
# error:  大v的进入还带来了他们的粉丝社群，那些错过微博红利期、具有大v潜质的准大v们也能建立起自己的粉丝社群，这又可以成为头条生态新的护城河粉丝关系链
# /home/lx/Projects/wjc/es/trainData/86.txt
# /home/lx/Projects/wjc/es/trainData/87.txt
# /home/lx/Projects/wjc/es/trainData/88.txt
# /home/lx/Projects/wjc/es/trainData/89.txt
# /home/lx/Projects/wjc/es/trainData/90.txt
# /home/lx/Projects/wjc/es/trainData/91.txt
# /home/lx/Projects/wjc/es/trainData/92.txt
# /home/lx/Projects/wjc/es/trainData/93.txt
# /home/lx/Projects/wjc/es/trainData/94.txt
# /home/lx/Projects/wjc/es/trainData/95.txt
# /home/lx/Projects/wjc/es/trainData/96.txt
# /home/lx/Projects/wjc/es/trainData/97.txt
# /home/lx/Projects/wjc/es/trainData/98.txt
# /home/lx/Projects/wjc/es/trainData/99.txt
# /home/lx/Projects/wjc/es/trainData/100.txt
# /home/lx/Projects/wjc/es/trainData/101.txt
# /home/lx/Projects/wjc/es/trainData/102.txt
# /home/lx/Projects/wjc/es/trainData/103.txt
# /home/lx/Projects/wjc/es/trainData/104.txt
# /home/lx/Projects/wjc/es/trainData/105.txt
# /home/lx/Projects/wjc/es/trainData/106.txt
# /home/lx/Projects/wjc/es/trainData/107.txt
# 'gbk' codec can't encode character '\u200b' in position 10: illegal multibyte sequence
# error:
# /home/lx/Projects/wjc/es/trainData/108.txt
# /home/lx/Projects/wjc/es/trainData/109.txt
# /home/lx/Projects/wjc/es/trainData/110.txt
# /home/lx/Projects/wjc/es/trainData/111.txt
# /home/lx/Projects/wjc/es/trainData/112.txt
# /home/lx/Projects/wjc/es/trainData/113.txt
# /home/lx/Projects/wjc/es/trainData/114.txt
# /home/lx/Projects/wjc/es/trainData/115.txt
# /home/lx/Projects/wjc/es/trainData/116.txt
# /home/lx/Projects/wjc/es/trainData/117.txt
# /home/lx/Projects/wjc/es/trainData/118.txt
# /home/lx/Projects/wjc/es/trainData/119.txt
# /home/lx/Projects/wjc/es/trainData/120.txt
# /home/lx/Projects/wjc/es/trainData/121.txt
# /home/lx/Projects/wjc/es/trainData/122.txt
# /home/lx/Projects/wjc/es/trainData/123.txt
# /home/lx/Projects/wjc/es/trainData/124.txt
# /home/lx/Projects/wjc/es/trainData/125.txt
# /home/lx/Projects/wjc/es/trainData/126.txt
# /home/lx/Projects/wjc/es/trainData/127.txt
# /home/lx/Projects/wjc/es/trainData/128.txt
# /home/lx/Projects/wjc/es/trainData/129.txt
# 'gbk' codec can't encode character '\u200b' in position 10: illegal multibyte sequence
# error:  二、快速学习事物的不二法则主持人：学习确实对于进阶是个非常重要的东西，创业包括投资，是一个不断面对新东西的过程，你如何学习，有没有一些听完之后，切实可用的方法可以和大家分享一下？傅盛：《得到》就很好啊
# /home/lx/Projects/wjc/es/trainData/130.txt
# /home/lx/Projects/wjc/es/trainData/131.txt
# /home/lx/Projects/wjc/es/trainData/132.txt
# /home/lx/Projects/wjc/es/trainData/133.txt
# /home/lx/Projects/wjc/es/trainData/134.txt
# /home/lx/Projects/wjc/es/trainData/135.txt
# /home/lx/Projects/wjc/es/trainData/136.txt
# /home/lx/Projects/wjc/es/trainData/137.txt
# /home/lx/Projects/wjc/es/trainData/138.txt
# /home/lx/Projects/wjc/es/trainData/139.txt
# /home/lx/Projects/wjc/es/trainData/140.txt
# /home/lx/Projects/wjc/es/trainData/141.txt
# /home/lx/Projects/wjc/es/trainData/142.txt
# 'gbk' codec can't encode character '\u200b' in position 18: illegal multibyte sequence
# /home/lx/Projects/wjc/es/trainData/501.txt
# /home/lx/Projects/wjc/es/trainData/502.txt
# /home/lx/Projects/wjc/es/trainData/503.txt
# /home/lx/Projects/wjc/es/trainData/504.txt
# /home/lx/Projects/wjc/es/trainData/505.txt
# /home/lx/Projects/wjc/es/trainData/506.txt
# /home/lx/Projects/wjc/es/trainData/507.txt
# /home/lx/Projects/wjc/es/trainData/508.txt
# /home/lx/Projects/wjc/es/trainData/509.txt
# /home/lx/Projects/wjc/es/trainData/510.txt
# /home/lx/Projects/wjc/es/trainData/511.txt
# /home/lx/Projects/wjc/es/trainData/512.txt
# /home/lx/Projects/wjc/es/trainData/513.txt
# /home/lx/Projects/wjc/es/trainData/514.txt
# /home/lx/Projects/wjc/es/trainData/515.txt
# /home/lx/Projects/wjc/es/trainData/516.txt
# /home/lx/Projects/wjc/es/trainData/517.txt
# /home/lx/Projects/wjc/es/trainData/518.txt
# /home/lx/Projects/wjc/es/trainData/519.txt
# /home/lx/Projects/wjc/es/trainData/520.txt
# /home/lx/Projects/wjc/es/trainData/521.txt
# /home/lx/Projects/wjc/es/trainData/522.txt
# /home/lx/Projects/wjc/es/trainData/523.txt
# /home/lx/Projects/wjc/es/trainData/524.txt
# /home/lx/Projects/wjc/es/trainData/525.txt
# /home/lx/Projects/wjc/es/trainData/526.txt
# /home/lx/Projects/wjc/es/trainData/527.txt
# /home/lx/Projects/wjc/es/trainData/528.txt
# /home/lx/Projects/wjc/es/trainData/529.txt
# /home/lx/Projects/wjc/es/trainData/530.txt
# /home/lx/Projects/wjc/es/trainData/531.txt

# %%
item = []
pos = []
flag = 0
corpus = open("./trainData_111111.txt", "w", encoding="utf-8")

with open("./trainData_111111.json", "r") as json_result:
    for line in json_result:
        line = line.strip()
        if "[" in line:
            continue
        if "{" in line:
            continue
        if "}" in line:
            continue
        if "]" in line:
            continue
        if "item" in line:
            item.append(line.replace(",","").split(":")[1].split('"')[1])
        elif "pos" in line and flag ==0:
            pos.append(line.split(":")[1].split('"')[1])
    dic = zip(item, pos)
    for key, value in dic:
        corpus.write(key+ " "+value + '\n')
    corpus.close()

# %% [markdown]
# ## 将测试集2/1分为验证集和测试集

# %% [markdown]
# ### 写反了 testData是38779-49858 valData是49859-55397

# %%
import shutil
for file in os.listdir(r'./testData'):
    number = int(file.split('.')[0]) 
    domain = os.path.abspath(r'./testData')  # 49859.txt-55397.txt
    file = os.path.join(domain, file)
    if 38779 <= number <= 49858: 
        shutil.copy(file, "./valData")  # 38779.txt-49858.txt
    else:
        continue

# %%
import shutil 
for file in os.listdir(r'./testData'):
    number = int(file.split('.')[0]) #获取文件名 *.txt 中的数字编号
    domain = os.path.abspath(r'./testData')
    file = os.path.join(domain, file) # 获取trainData下的所有文件
    if 38779 <= number <= 49858: 
        os.remove(file)

# %%
import json
json.loads(open('trainData_1.json').read())
# Out:
# [[{'item': 'AI', 'pos': 'nz'},
#   {'item': '产品经理', 'pos': 'ti'},
#   {'item': '需要', 'pos': 'v'},
#   {'item': '了解', 'pos': 'vn'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '交互', 'pos': 'vn'},
#   {'item': '评价', 'pos': 'vn'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': '编者按', 'pos': 'n'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '本文', 'pos': 'n'},
#   {'item': '来自', 'pos': 'v'},
#   {'item': '微信公众号', 'pos': 'nz'},
#   {'item': '"', 'pos': 'w'},
#   {'item': 'hanniman', 'pos': 'nz'},
#   {'item': '"', 'pos': 'w'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'ID', 'pos': 'nz'},
#   {'item': '：', 'pos': 'w'},
#   {'item': 'hanniman', 'pos': 'v'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '作者', 'pos': 'n'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '黄钊', 'pos': 'nr'},
#   {'item': 'hanniman', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '图灵机器人', 'pos': 'nz'},
#   {'item': '-', 'pos': 'w'},
#   {'item': '人才', 'pos': 'n'},
#   {'item': '战略', 'pos': 'n'},
#   {'item': '官', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '前', 'pos': 'f'},
#   {'item': '腾讯', 'pos': 'nt'},
#   {'item': '产品经理', 'pos': 'ti'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '36氪', 'pos': 'nz'},
#   {'item': '经', 'pos': 'p'},
#   {'item': '授权', 'pos': 'vn'},
#   {'item': '发布', 'pos': 'v'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '最近', 'pos': 't'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '饭团', 'pos': 'n'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'AI', 'pos': 'nz'},
#   {'item': '产品经理', 'pos': 'ti'},
#   {'item': '大本营', 'pos': 'n'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '里', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '团员', 'pos': 'n'},
#   {'item': '提问', 'pos': 'vn'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '如何', 'pos': 'r'},
#   {'item': '制定', 'pos': 'v'},
#   {'item': '针对', 'pos': 'p'},
#   {'item': '自然', 'pos': 'n'},
#   {'item': '语言', 'pos': 'n'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '交互', 'pos': 'v'},
#   {'item': '系统', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '评价', 'pos': 'vn'},
#   {'item': '体系', 'pos': 'n'},
#   {'item': '？', 'pos': 'w'},
#   {'item': '有没有', 'pos': 'v'},
#   {'item': '通用', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '标准', 'pos': 'n'},
#   {'item': '？', 'pos': 'w'},
#   {'item': '例如', 'pos': 'c'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '车载', 'pos': 'vn'},
#   {'item': '环境', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '站', 'pos': 'v'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '角度', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '从', 'pos': 'p'},
#   {'item': '客观', 'pos': 'a'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '主观', 'pos': 'a'},
#   {'item': '角度', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '评价', 'pos': 'vn'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '？', 'pos': 'w'},
#   {'item': '上周', 'pos': 't'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '我', 'pos': 'r'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '专属', 'pos': 'a'},
#   {'item': '微信群', 'pos': 'n'},
#   {'item': '内', 'pos': 'f'},
#   {'item': '抛出', 'pos': 'v'},
#   {'item': '了', 'pos': 'u'},
#   {'item': '这个', 'pos': 'r'},
#   {'item': '问题', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '当晚', 'pos': 't'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '@', 'pos': 'w'},
#   {'item': '胡含', 'pos': 'nr'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '@', 'pos': 'w'},
#   {'item': '我', 'pos': 'r'},
#   {'item': '偏', 'pos': 'd'},
#   {'item': '笑', 'pos': 'v'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '@艳龙', 'pos': 'nr'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': '等', 'pos': 'v'},
#   {'item': '朋友', 'pos': 'n'},
#   {'item': '就', 'pos': 'd'},
#   {'item': '分享', 'pos': 'v'},
#   {'item': '了', 'pos': 'u'},
#   {'item': '不少', 'pos': 'm'},
#   {'item': '干货', 'pos': 'n'},
#   {'item': '心得', 'pos': 'n'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '最近几天', 'pos': 't'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '@飞艳', 'pos': 'nr'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': '同学', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '协助', 'pos': 'v'},
#   {'item': '整理', 'pos': 'v'},
#   {'item': '下', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '我', 'pos': 'r'},
#   {'item': '又', 'pos': 'd'},
#   {'item': '补充', 'pos': 'v'},
#   {'item': '了', 'pos': 'u'},
#   {'item': '一些', 'pos': 'm'},
#   {'item': '信息', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '最终', 'pos': 'ad'},
#   {'item': '形成', 'pos': 'v'},
#   {'item': '这', 'pos': 'r'},
#   {'item': '篇', 'pos': 'q'},
#   {'item': '文章', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '以', 'pos': 'p'},
#   {'item': '飨', 'pos': 'v'},
#   {'item': '大家', 'pos': 'r'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '本文', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '具体', 'pos': 'ad'},
#   {'item': '介绍', 'pos': 'v'},
#   {'item': '了', 'pos': 'u'},
#   {'item': '下面', 'pos': 'f'},
#   {'item': '5', 'pos': 'm'},
#   {'item': '大', 'pos': 'a'},
#   {'item': '方面', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '行业', 'pos': 'n'},
#   {'item': '实战', 'pos': 'n'},
#   {'item': '评价', 'pos': 'vn'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '一', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '识别', 'pos': 'vn'},
#   {'item': '二', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '自然语言处理', 'pos': 'nz'},
#   {'item': '三', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '合成', 'pos': 'v'},
#   {'item': '四', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '对话', 'pos': 'v'},
#   {'item': '系统', 'pos': 'n'},
#   {'item': '五', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '整体', 'pos': 'n'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '数据', 'pos': 'n'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '1', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': 'ASR语音识别', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'Automatic', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Speech', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Recognition', 'pos': 'xc'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': '简称', 'pos': 'v'},
#   {'item': 'ASR', 'pos': 'nz'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '将', 'pos': 'p'},
#   {'item': '声音', 'pos': 'n'},
#   {'item': '转化', 'pos': 'v'},
#   {'item': '为', 'pos': 'v'},
#   {'item': '文字', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '过程', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '相当于', 'pos': 'v'},
#   {'item': '人类', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '耳朵', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '1', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '识别率', 'pos': 'n'},
#   {'item': '看', 'pos': 'v'},
#   {'item': '纯', 'pos': 'a'},
#   {'item': '引擎', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '识别率', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '以及', 'pos': 'c'},
#   {'item': '不同', 'pos': 'a'},
#   {'item': '信噪比', 'pos': 'n'},
#   {'item': '状态', 'pos': 'n'},
#   {'item': '下', 'pos': 'f'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '识别率', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '信噪比', 'pos': 'n'},
#   {'item': '模拟', 'pos': 'v'},
#   {'item': '不同', 'pos': 'a'},
#   {'item': '车速', 'pos': 'n'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '车窗', 'pos': 'n'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '空调', 'pos': 'n'},
#   {'item': '状态', 'pos': 'n'},
#   {'item': '等', 'pos': 'u'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '还有', 'pos': 'v'},
#   {'item': '在线', 'pos': 'vn'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '离线', 'pos': 'vd'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '区别', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '实际', 'pos': 'a'},
#   {'item': '工作', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': '识别率', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '直接', 'pos': 'a'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'WER', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '错误率', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'Word', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Error', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Rate', 'pos': 'xc'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '定义', 'pos': 'n'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '为了', 'pos': 'p'},
#   {'item': '使', 'pos': 'v'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '出来', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '序列', 'pos': 'n'},
#   {'item': '和', 'pos': 'c'},
#   {'item': '标准', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '序列', 'pos': 'n'},
#   {'item': '之间', 'pos': 'f'},
#   {'item': '保持', 'pos': 'v'},
#   {'item': '一致', 'pos': 'an'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '需要', 'pos': 'v'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '替换', 'pos': 'vn'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '删除', 'pos': 'vn'},
#   {'item': '或者', 'pos': 'c'},
#   {'item': '插入', 'pos': 'v'},
#   {'item': '某些', 'pos': 'r'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '这些', 'pos': 'r'},
#   {'item': '插入', 'pos': 'v'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '替换', 'pos': 'v'},
#   {'item': '或', 'pos': 'c'},
#   {'item': '删除', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '总', 'pos': 'a'},
#   {'item': '个', 'pos': 'q'},
#   {'item': '数', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '除以', 'pos': 'v'},
#   {'item': '标准', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '序列', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '总', 'pos': 'a'},
#   {'item': '个', 'pos': 'q'},
#   {'item': '数', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '百分比', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '即', 'pos': 'd'},
#   {'item': '为', 'pos': 'v'},
#   {'item': 'WER', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '公式', 'pos': 'n'},
#   {'item': '为', 'pos': 'v'},
#   {'item': '：', 'pos': 'w'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Substitution', 'pos': 'vd'},
#   {'item': '替换', 'pos': 'v'},
#   {'item': 'Deletion', 'pos': 'n'},
#   {'item': '删除', 'pos': 'v'},
#   {'item': 'Insertion', 'pos': 'n'},
#   {'item': '插入', 'pos': 'v'},
#   {'item': 'N', 'pos': 'xc'},
#   {'item': '单词', 'pos': 'n'},
#   {'item': '数目', 'pos': 'n'},
#   {'item': '3点', 'pos': 't'},
#   {'item': '说明', 'pos': 'v'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'WER', 'pos': 'nz'},
#   {'item': '可以', 'pos': 'v'},
#   {'item': '分', 'pos': 'v'},
#   {'item': '男女', 'pos': 'n'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '快慢', 'pos': 'n'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '口音', 'pos': 'n'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '数字', 'pos': 'n'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '英文', 'pos': 'nz'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '中文', 'pos': 'nz'},
#   {'item': '等', 'pos': 'u'},
#   {'item': '情况', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '分别', 'pos': 'd'},
#   {'item': '来看', 'pos': 'v'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '因为', 'pos': 'p'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '插入', 'pos': 'v'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '所以', 'pos': 'c'},
#   {'item': '理论', 'pos': 'n'},
#   {'item': '上', 'pos': 'f'},
#   {'item': 'WER', 'pos': 'n'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '可能', 'pos': 'n'},
#   {'item': '大于', 'pos': 'v'},
#   {'item': '100%', 'pos': 'm'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '但', 'pos': 'c'},
#   {'item': '实际', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '特别', 'pos': 'd'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '大', 'pos': 'a'},
#   {'item': '样本', 'pos': 'n'},
#   {'item': '量', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '时候', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '可能', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '否则', 'pos': 'c'},
#   {'item': '就', 'pos': 'd'},
#   {'item': '太', 'pos': 'd'},
#   {'item': '差', 'pos': 'a'},
#   {'item': '了', 'pos': 'xc'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '可能', 'pos': 'v'},
#   {'item': '被', 'pos': 'p'},
#   {'item': '商用', 'pos': 'v'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '站', 'pos': 'v'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '纯', 'pos': 'a'},
#   {'item': '产品', 'pos': 'n'},
#   {'item': '体验', 'pos': 'vn'},
#   {'item': '角度', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '很多人', 'pos': 'n'},
#   {'item': '会', 'pos': 'v'},
#   {'item': '以为', 'pos': 'v'},
#   {'item': '识别率', 'pos': 'n'},
#   {'item': '应该', 'pos': 'v'},
#   {'item': '等于', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '句子', 'pos': 'n'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '正确', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '个', 'pos': 'q'},
#   {'item': '数', 'pos': 'm'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '总', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '句子', 'pos': 'n'},
#   {'item': '个', 'pos': 'q'},
#   {'item': '数', 'pos': 'n'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '即', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '正确', 'pos': 'a'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '率', 'pos': 'v'},
#   {'item': '等于', 'pos': 'v'},
#   {'item': '96%', 'pos': 'm'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '这种', 'pos': 'r'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '实际', 'pos': 'a'},
#   {'item': '工作', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '这个', 'pos': 'r'},
#   {'item': '应该', 'pos': 'v'},
#   {'item': '指向', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'SER', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '句', 'pos': 'q'},
#   {'item': '错误率', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'Sentence', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Error', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Rate', 'pos': 'xc'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '即', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '句子', 'pos': 'n'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '错误', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '个', 'pos': 'q'},
#   {'item': '数', 'pos': 'm'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '总', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '句子', 'pos': 'n'},
#   {'item': '个', 'pos': 'q'},
#   {'item': '数', 'pos': 'n'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '不过', 'pos': 'c'},
#   {'item': '据说', 'pos': 'n'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '实际', 'pos': 'a'},
#   {'item': '工作', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': '句', 'pos': 'q'},
#   {'item': '错误率', 'pos': 'n'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '字', 'pos': 'n'},
#   {'item': '错误率', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '2', 'pos': 'm'},
#   {'item': '~', 'pos': 'w'},
#   {'item': '3倍', 'pos': 'm'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '所以', 'pos': 'c'},
#   {'item': '可能', 'pos': 'v'},
#   {'item': '就', 'pos': 'd'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '怎么', 'pos': 'r'},
#   {'item': '看', 'pos': 'v'},
#   {'item': '了', 'pos': 'xc'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '2', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '唤醒', 'pos': 'v'},
#   {'item': '相关', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '先', 'pos': 'd'},
#   {'item': '需要', 'pos': 'v'},
#   {'item': '介绍', 'pos': 'v'},
#   {'item': '下', 'pos': 'q'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '唤醒', 'pos': 'v'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'Voice Trigger', 'pos': 'nz'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'VT', 'pos': 'xc'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '相关', 'pos': 'vn'},
#   {'item': '信息', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': 'A', 'pos': 'xc'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '唤醒', 'pos': 'vn'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '需求', 'pos': 'n'},
#   {'item': '背景', 'pos': 'n'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '近场', 'pos': 'n'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '时', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '比如', 'pos': 'v'},
#   {'item': '使用', 'pos': 'v'},
#   {'item': '语音输入法', 'pos': 'nz'},
#   {'item': '时', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '可以', 'pos': 'v'},
#   {'item': '按住', 'pos': 'v'},
#   {'item': '手机', 'pos': 'n'},
#   {'item': '上', 'pos': 'f'},
#   {'item': 'siri', 'pos': 'nz'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '按钮', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '直接', 'pos': 'ad'},
#   {'item': '说话', 'pos': 'v'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '结束', 'pos': 'v'},
#   {'item': '之后', 'pos': 'f'},
#   {'item': '松开', 'pos': 'v'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '近场', 'pos': 'n'},
#   {'item': '情况', 'pos': 'n'},
#   {'item': '下', 'pos': 'f'},
#   {'item': '信噪比', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'Signal', 'pos': 'nz'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'to', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Noise', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Ratio', 'pos': 'xc'},
#   {'item': ',', 'pos': 'w'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'SNR', 'pos': 'nz'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '比较', 'pos': 'd'},
#   {'item': '高', 'pos': 'a'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '信号', 'pos': 'n'},
#   {'item': '清晰', 'pos': 'a'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '简单', 'pos': 'a'},
#   {'item': '算法', 'pos': 'n'},
#   {'item': '也', 'pos': 'd'},
#   {'item': '能', 'pos': 'v'},
#   {'item': '做到', 'pos': 'v'},
#   {'item': '有效', 'pos': 'a'},
#   {'item': '可靠', 'pos': 'a'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '但是', 'pos': 'c'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '远场', 'pos': 's'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '时', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '比如', 'pos': 'v'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '智能', 'pos': 'n'},
#   {'item': '音箱', 'pos': 'n'},
#   {'item': '场景', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '不能', 'pos': 'v'},
#   {'item': '用', 'pos': 'p'},
#   {'item': '手', 'pos': 'n'},
#   {'item': '接触', 'pos': 'v'},
#   {'item': '设备', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '需要', 'pos': 'v'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '唤醒', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '相当于', 'pos': 'v'},
#   {'item': '叫', 'pos': 'v'},
#   {'item': '这个', 'pos': 'r'},
#   {'item': 'AI', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '机器人', 'pos': 'n'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '名字', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '引起', 'pos': 'v'},
#   {'item': 'ta', 'pos': 'r'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '注意', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '比如', 'pos': 'v'},
#   {'item': '苹果', 'pos': 'nt'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'Hey Siri', 'pos': 'nz'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'Google', 'pos': 'nt'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'OK', 'pos': 'n'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Google', 'pos': 'nz'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '亚马逊', 'pos': 'nz'},
#   {'item': 'Echo', 'pos': 'nz'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'Alexa', 'pos': 'nz'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '等', 'pos': 'u'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': 'B', 'pos': 'xc'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '唤醒', 'pos': 'vn'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '含义', 'pos': 'n'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '简单', 'pos': 'ad'},
#   {'item': '来说', 'pos': 'v'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '喊', 'pos': 'v'},
#   {'item': '名字', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '引起', 'pos': 'v'},
#   {'item': '听者', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'AI', 'pos': 'nz'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '注意', 'pos': 'vn'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '如果', 'pos': 'c'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '唤醒', 'pos': 'v'},
#   {'item': '判断', 'pos': 'vn'},
#   {'item': '结果', 'pos': 'n'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '正确', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '唤醒', 'pos': 'vn'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '激活', 'pos': 'v'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '那', 'pos': 'r'},
#   {'item': '后续', 'pos': 'vn'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '就', 'pos': 'd'},
#   {'item': '应该', 'pos': 'v'},
#   {'item': '被', 'pos': 'p'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '否则', 'pos': 'c'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '识别', 'pos': 'vn'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': 'C', 'pos': 'xc'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '唤醒', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '相关', 'pos': 'vn'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '唤醒率', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '叫', 'pos': 'v'},
#   {'item': 'AI', 'pos': 'nz'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '时候', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'ta', 'pos': 'r'},
#   {'item': '成功', 'pos': 'ad'},
#   {'item': '被', 'pos': 'p'},
#   {'item': '唤醒', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '比率', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '误唤醒率', 'pos': 'nz'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '没', 'pos': 'v'},
#   {'item': '叫', 'pos': 'v'},
#   {'item': 'AI', 'pos': 'nz'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '时候', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'ta', 'pos': 'r'},
#   {'item': '自己', 'pos': 'r'},
#   {'item': '跳出来', 'pos': 'v'},
#   {'item': '讲话', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '比率', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '如果', 'pos': 'c'},
#   {'item': '误', 'pos': 'v'},
#   {'item': '唤醒', 'pos': 'v'},
#   {'item': '比较', 'pos': 'd'},
#   {'item': '多', 'pos': 'a'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '特别', 'pos': 'd'},
#   {'item': '比如', 'pos': 'v'},
#   {'item': '半夜', 'pos': 't'},
#   {'item': '时', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '智能', 'pos': 'n'},
#   {'item': '音箱', 'pos': 'n'},
#   {'item': '突然', 'pos': 'ad'},
#   {'item': '开始', 'pos': 'v'},
#   {'item': '唱歌', 'pos': 'vn'},
#   {'item': '或', 'pos': 'c'},
#   {'item': '讲故事', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '会', 'pos': 'v'},
#   {'item': '特别', 'pos': 'd'},
#   {'item': '吓人', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '…', 'pos': 'w'},
#   {'item': '…', 'pos': 'w'},
#   {'item': '唤醒', 'pos': 'v'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '音节', 'pos': 'n'},
#   {'item': '长度', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '一般', 'pos': 'a'},
#   {'item': '技术', 'pos': 'n'},
#   {'item': '上', 'pos': 'f'},
#   {'item': '要求', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '最少', 'pos': 'd'},
#   {'item': '3个', 'pos': 'm'},
#   {'item': '音节', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '比如', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'OK', 'pos': 'v'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Google', 'pos': 'nz'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '和', 'pos': 'c'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'Alexa', 'pos': 'nz'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '四个', 'pos': 'm'},
#   {'item': '音节', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'Hey Siri', 'pos': 'nz'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '三个', 'pos': 'm'},
#   {'item': '音节', 'pos': 'n'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '国内', 'pos': 's'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '智能', 'pos': 'n'},
#   {'item': '音箱', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '比如', 'pos': 'v'},
#   {'item': '小雅', 'pos': 'nr'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '唤醒', 'pos': 'v'},
#   {'item': '词', 'pos': 'n'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '小雅', 'pos': 'nr'},
#   {'item': '小雅', 'pos': 'nr'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '而', 'pos': 'c'},
#   {'item': '不能', 'pos': 'v'},
#   {'item': '用', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '小雅', 'pos': 'nr'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '如果', 'pos': 'c'},
#   {'item': '音节', 'pos': 'n'},
#   {'item': '太短', 'pos': 'a'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': '误', 'pos': 'v'},
#   {'item': '唤醒率', 'pos': 'nz'},
#   {'item': '会', 'pos': 'v'},
#   {'item': '比较', 'pos': 'd'},
#   {'item': '高', 'pos': 'a'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '唤醒', 'pos': 'v'},
#   {'item': '响应', 'pos': 'vn'},
#   {'item': '时间', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '之前', 'pos': 'f'},
#   {'item': '看', 'pos': 'v'},
#   {'item': '过', 'pos': 'u'},
#   {'item': '傅盛', 'pos': 'nr'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '文章', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '说', 'pos': 'v'},
#   {'item': '世界上', 'pos': 's'},
#   {'item': '所有', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '音箱', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '除了', 'pos': 'p'},
#   {'item': 'Echo', 'pos': 'n'},
#   {'item': '和', 'pos': 'c'},
#   {'item': '他们', 'pos': 'r'},
#   {'item': '做', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '小雅', 'pos': 'a'},
#   {'item': '智能', 'pos': 'n'},
#   {'item': '音箱', 'pos': 'n'},
#   {'item': '能', 'pos': 'v'},
#   {'item': '达到', 'pos': 'v'},
#   {'item': '1.5秒', 'pos': 't'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '其他', 'pos': 'r'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '都', 'pos': 'd'},
#   {'item': '在', 'pos': 'v'},
#   {'item': '3秒以上', 'pos': 't'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '功耗', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '要', 'pos': 'v'},
#   {'item': '低', 'pos': 'a'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '看', 'pos': 'v'},
#   {'item': '过', 'pos': 'u'},
#   {'item': '报道', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '说', 'pos': 'v'},
#   {'item': 'iPhone', 'pos': 'nz'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': '4s', 'pos': 'nz'},
#   {'item': '出现', 'pos': 'v'},
#   {'item': 'Siri', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '但', 'pos': 'c'},
#   {'item': '直到', 'pos': 'p'},
#   {'item': 'iPhone', 'pos': 'nz'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': '6s', 'pos': 'nz'},
#   {'item': '之后', 'pos': 'f'},
#   {'item': '才', 'pos': 'd'},
#   {'item': '允许', 'pos': 'v'},
#   {'item': '不接', 'pos': 'v'},
#   {'item': '电源', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '情况', 'pos': 'n'},
#   {'item': '下', 'pos': 'f'},
#   {'item': '直接', 'pos': 'ad'},
#   {'item': '喊', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'Hey Siri', 'pos': 'nz'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '唤醒', 'pos': 'vn'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '这', 'pos': 'r'},
#   {'item': '是因为', 'pos': 'v'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '6s', 'pos': 'n'},
#   {'item': '上', 'pos': 'f'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '一颗', 'pos': 'm'},
#   {'item': '专门', 'pos': 'd'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '激活', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '低功耗', 'pos': 'n'},
#   {'item': '芯片', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '当然', 'pos': 'd'},
#   {'item': '算法', 'pos': 'n'},
#   {'item': '和', 'pos': 'c'},
#   {'item': '硬件', 'pos': 'n'},
#   {'item': '要', 'pos': 'v'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '配合', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '算法', 'pos': 'n'},
#   {'item': '也', 'pos': 'd'},
#   {'item': '要', 'pos': 'v'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '优化', 'pos': 'vn'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '以上', 'pos': 'f'},
#   {'item': '1', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '2', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '3', 'pos': 'm'},
#   {'item': '相对', 'pos': 'd'},
#   {'item': '更重要', 'pos': 'a'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': 'D', 'pos': 'xc'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '其他', 'pos': 'r'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': '涉及', 'pos': 'v'},
#   {'item': 'AEC', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '自适应', 'pos': 'vn'},
#   {'item': '回声', 'pos': 'n'},
#   {'item': '消除', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'Automatic', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Echo', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Cancellation', 'pos': 'xc'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '还要', 'pos': 'v'},
#   {'item': '考察', 'pos': 'v'},
#   {'item': 'WER', 'pos': 'nz'},
#   {'item': '相对', 'pos': 'd'},
#   {'item': '改善', 'pos': 'v'},
#   {'item': '情况', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '2', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '自然语言处理', 'pos': 'nz'},
#   {'item': 'NLP', 'pos': 'nz'},
#   {'item': '自然语言处理', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'Natural', 'pos': 'nz'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Language Processing', 'pos': 'nz'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': '简称', 'pos': 'v'},
#   {'item': 'NLP', 'pos': 'nz'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '通俗', 'pos': 'a'},
#   {'item': '理解', 'pos': 'vn'},
#   {'item': '就是', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '让', 'pos': 'v'},
#   {'item': '计算机', 'pos': 'n'},
#   {'item': '能够', 'pos': 'v'},
#   {'item': '理解', 'pos': 'v'},
#   {'item': '和', 'pos': 'c'},
#   {'item': '生成', 'pos': 'v'},
#   {'item': '人类', 'pos': 'n'},
#   {'item': '语言', 'pos': 'n'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '1', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '准确率', 'pos': 'n'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '召回率', 'pos': 'nz'},
#   {'item': '附上', 'pos': 'v'},
#   {'item': '之', 'pos': 'u'},
#   {'item': '前', 'pos': 'f'},
#   {'item': '文章', 'pos': 'n'},
#   {'item': '《', 'pos': 'w'},
#   {'item': 'AI', 'pos': 'nz'},
#   {'item': '产品经理', 'pos': 'ti'},
#   {'item': '需要', 'pos': 'v'},
#   {'item': '了解', 'pos': 'vn'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '数据', 'pos': 'n'},
#   {'item': '标注', 'pos': 'vn'},
#   {'item': '工作', 'pos': 'n'},
#   {'item': '入门', 'pos': 'vn'},
#   {'item': '》', 'pos': 'w'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '分享', 'pos': 'v'},
#   {'item': '过', 'pos': 'u'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '一段', 'pos': 'm'},
#   {'item': '解释', 'pos': 'vn'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '准确率', 'pos': 'n'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '为', 'pos': 'v'},
#   {'item': '正确', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '样本', 'pos': 'n'},
#   {'item': '数', 'pos': 'm'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '出来', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '样本', 'pos': 'n'},
#   {'item': '数', 'pos': 'n'},
#   {'item': '召回率', 'pos': 'n'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '为', 'pos': 'v'},
#   {'item': '正确', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '样本', 'pos': 'n'},
#   {'item': '数', 'pos': 'n'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '所有', 'pos': 'r'},
#   {'item': '样本', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '正确', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '数', 'pos': 'n'},
#   {'item': '举个栗子', 'pos': 'nt'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '全班', 'pos': 'n'},
#   {'item': '一共', 'pos': 'd'},
#   {'item': '30名', 'pos': 'm'},
#   {'item': '男生', 'pos': 'n'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '20名', 'pos': 'm'},
#   {'item': '女生', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '需要', 'pos': 'v'},
#   {'item': '机器', 'pos': 'n'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '出', 'pos': 'v'},
#   {'item': '男生', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '数量', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '本次', 'pos': 'r'},
#   {'item': '机器', 'pos': 'n'},
#   {'item': '一共', 'pos': 'd'},
#   {'item': '识别', 'pos': 'v'},
#   {'item': '出', 'pos': 'v'},
#   {'item': '20名', 'pos': 'm'},
#   {'item': '目标', 'pos': 'n'},
#   {'item': '对象', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '其中', 'pos': 'r'},
#   {'item': '18', 'pos': 'm'},
#   {'item': '名', 'pos': 'n'},
#   {'item': '为', 'pos': 'v'},
#   {'item': '男性', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '2名', 'pos': 'm'},
#   {'item': '为', 'pos': 'v'},
#   {'item': '女性', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '则', 'pos': 'c'},
#   {'item': '精确率', 'pos': 'n'},
#   {'item': '=', 'pos': 'w'},
#   {'item': '18', 'pos': 'm'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '18', 'pos': 'm'},
#   {'item': '+', 'pos': 'w'},
#   {'item': '2', 'pos': 'm'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '=', 'pos': 'w'},
#   {'item': '0.9', 'pos': 'm'},
#   {'item': '召回率', 'pos': 'nz'},
#   {'item': '=', 'pos': 'w'},
#   {'item': '18', 'pos': 'm'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '30', 'pos': 'q'},
#   {'item': '=', 'pos': 'w'},
#   {'item': '0.6', 'pos': 'q'},
#   {'item': '再', 'pos': 'd'},
#   {'item': '补充', 'pos': 'v'},
#   {'item': '一个', 'pos': 'm'},
#   {'item': '图', 'pos': 'n'},
#   {'item': '来', 'pos': 'v'},
#   {'item': '解释', 'pos': 'v'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '2', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': 'F1值', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '精准率', 'pos': 'n'},
#   {'item': '和', 'pos': 'c'},
#   {'item': '召回率', 'pos': 'nz'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '调和平均数', 'pos': 'nz'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '模型', 'pos': 'n'},
#   {'item': '调优', 'pos': 'v'},
#   {'item': '后', 'pos': 'f'},
#   {'item': '追求', 'pos': 'v'},
#   {'item': 'F1', 'pos': 'nz'},
#   {'item': '值', 'pos': 'n'},
#   {'item': '提升', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '准确率', 'pos': 'n'},
#   {'item': '召回率', 'pos': 'n'},
#   {'item': '单独', 'pos': 'd'},
#   {'item': '下降', 'pos': 'v'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '一个', 'pos': 'm'},
#   {'item': '小区', 'pos': 'n'},
#   {'item': '间', 'pos': 'f'},
#   {'item': '内', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '整体', 'pos': 'n'},
#   {'item': 'F1', 'pos': 'nz'},
#   {'item': '值', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '增量', 'pos': 'n'},
#   {'item': '也是', 'pos': 'v'},
#   {'item': '分', 'pos': 'v'},
#   {'item': '区间', 'pos': 'n'},
#   {'item': '看', 'pos': 'v'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'F1', 'pos': 'nz'},
#   {'item': '值', 'pos': 'n'},
#   {'item': '在', 'pos': 'v'},
#   {'item': '60%', 'pos': 'm'},
#   {'item': '内', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '与', 'pos': 'p'},
#   {'item': '60%', 'pos': 'm'},
#   {'item': '以上', 'pos': 'f'},
#   {'item': '肯定', 'pos': 'd'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '不一样', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '90%', 'pos': 'm'},
#   {'item': '以上', 'pos': 'f'},
#   {'item': '可能', 'pos': 'v'},
#   {'item': '只', 'pos': 'd'},
#   {'item': '追求', 'pos': 'v'},
#   {'item': '1%', 'pos': 'm'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '提升', 'pos': 'vn'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': 'P', 'pos': 'xc'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '精准率', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'R', 'pos': 'xc'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '召回率', 'pos': 'nz'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'Fa', 'pos': 'nz'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '在', 'pos': 'p'},
#   {'item': 'F1', 'pos': 'nz'},
#   {'item': '基础', 'pos': 'n'},
#   {'item': '上', 'pos': 'f'},
#   {'item': '做', 'pos': 'v'},
#   {'item': '了', 'pos': 'u'},
#   {'item': '赋权', 'pos': 'vn'},
#   {'item': '处理', 'pos': 'vn'},
#   {'item': '：', 'pos': 'w'},
#   {'item': 'Fa', 'pos': 'xc'},
#   {'item': '=', 'pos': 'w'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'a', 'pos': 'xc'},
#   {'item': '^', 'pos': 'w'},
#   {'item': '2', 'pos': 'm'},
#   {'item': '+', 'pos': 'w'},
#   {'item': '1', 'pos': 'm'},
#   {'item': '）', 'pos': 'w'},
#   {'item': 'PR', 'pos': 'ti'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'a', 'pos': 'xc'},
#   {'item': '^', 'pos': 'xc'},
#   {'item': '2P', 'pos': 'xc'},
#   {'item': '+', 'pos': 'xc'},
#   {'item': 'R', 'pos': 'xc'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '3', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '语音合成', 'pos': 'nz'},
#   {'item': 'TTS', 'pos': 'nz'},
#   {'item': '语音合成', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'Text', 'pos': 'nz'},
#   {'item': '-', 'pos': 'w'},
#   {'item': 'To', 'pos': 'nz'},
#   {'item': '-', 'pos': 'w'},
#   {'item': 'Speech', 'pos': 'nz'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': '简称', 'pos': 'v'},
#   {'item': 'TTS', 'pos': 'nz'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '将', 'pos': 'p'},
#   {'item': '文字', 'pos': 'n'},
#   {'item': '转化', 'pos': 'v'},
#   {'item': '为', 'pos': 'v'},
#   {'item': '声音', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '朗读', 'pos': 'v'},
#   {'item': '出来', 'pos': 'v'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '类比', 'pos': 'v'},
#   {'item': '于', 'pos': 'p'},
#   {'item': '人类', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '嘴巴', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '大家', 'pos': 'r'},
#   {'item': '在', 'pos': 'p'},
#   {'item': 'Siri', 'pos': 'nt'},
#   {'item': '等', 'pos': 'u'},
#   {'item': '各种', 'pos': 'r'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '助手', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '听到', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '声音', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '都是', 'pos': 'v'},
#   {'item': '由', 'pos': 'p'},
#   {'item': 'TTS', 'pos': 'nz'},
#   {'item': '来', 'pos': 'v'},
#   {'item': '生成', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '并', 'pos': 'd'},
#   {'item': '不是', 'pos': 'v'},
#   {'item': '真人', 'pos': 'n'},
#   {'item': '在', 'pos': 'd'},
#   {'item': '说话', 'pos': 'v'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '主观', 'pos': 'a'},
#   {'item': '测试', 'pos': 'vn'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '自然度', 'pos': 'nz'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '以', 'pos': 'p'},
#   {'item': 'MOS', 'pos': 'nz'},
#   {'item': '为主', 'pos': 'v'},
#   {'item': '：', 'pos': 'w'},
#   {'item': 'MOS', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'Mean', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Opinion', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Scores', 'pos': 'xc'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '专家', 'pos': 'ti'},
#   {'item': '级', 'pos': 'n'},
#   {'item': '评测', 'pos': 'v'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '主观', 'pos': 'a'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '1', 'pos': 'm'},
#   {'item': '-', 'pos': 'w'},
#   {'item': '5分', 'pos': 'm'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '5分', 'pos': 'm'},
#   {'item': '最好', 'pos': 'a'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': 'ABX', 'pos': 'nt'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '普通', 'pos': 'a'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '评测', 'pos': 'v'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '主观', 'pos': 'a'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '让', 'pos': 'v'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '来', 'pos': 'v'},
#   {'item': '视听', 'pos': 'n'},
#   {'item': '两个', 'pos': 'm'},
#   {'item': 'TTS', 'pos': 'nz'},
#   {'item': '系统', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '对比', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '看', 'pos': 'v'},
#   {'item': '哪个', 'pos': 'r'},
#   {'item': '好', 'pos': 'a'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '客观', 'pos': 'ad'},
#   {'item': '测试', 'pos': 'v'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '对', 'pos': 'p'},
#   {'item': '声学', 'pos': 'n'},
#   {'item': '参数', 'pos': 'n'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '评估', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '计算', 'pos': 'v'},
#   {'item': '欧式', 'pos': 'a'},
#   {'item': '距离', 'pos': 'n'},
#   {'item': '等', 'pos': 'u'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'RMSE', 'pos': 'nz'},
#   {'item': '，', 'pos': 'w'},
#   {'item': 'LSD', 'pos': 'nz'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '对', 'pos': 'p'},
#   {'item': '工程', 'pos': 'n'},
#   {'item': '上', 'pos': 'f'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '测试', 'pos': 'vn'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '实时', 'pos': 'd'},
#   {'item': '率', 'pos': 'v'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '合成', 'pos': 'vn'},
#   {'item': '耗时', 'pos': 'v'},
#   {'item': '/', 'pos': 'w'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '时', 'pos': 'n'},
#   {'item': '长', 'pos': 'n'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '流式', 'pos': 'n'},
#   {'item': '分', 'pos': 'v'},
#   {'item': '首包', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '尾包', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '非流式', 'pos': 'a'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '考察', 'pos': 'v'},
#   {'item': '首包', 'pos': 'm'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '首包', 'pos': 'm'},
#   {'item': '响应', 'pos': 'vn'},
#   {'item': '时间', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '发出', 'pos': 'v'},
#   {'item': '请求', 'pos': 'v'},
#   {'item': '到', 'pos': 'v'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '感知', 'pos': 'v'},
#   {'item': '到', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '第一包', 'pos': 'm'},
#   {'item': '到达', 'pos': 'vn'},
#   {'item': '时间', 'pos': 'n'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '内存', 'pos': 'n'},
#   {'item': '占用', 'pos': 'vn'},
#   {'item': '、', 'pos': 'w'},
#   {'item': 'CPU', 'pos': 'nz'},
#   {'item': '占用', 'pos': 'v'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '3', 'pos': 'm'},
#   {'item': '*', 'pos': 'w'},
#   {'item': '24小时', 'pos': 't'},
#   {'item': 'crash率', 'pos': 'nz'},
#   {'item': '等', 'pos': 'u'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '4', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '对话', 'pos': 'v'},
#   {'item': '系统', 'pos': 'n'},
#   {'item': '对话', 'pos': 'vn'},
#   {'item': '系统', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'Dialogue System', 'pos': 'nz'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '简单', 'pos': 'a'},
#   {'item': '可以', 'pos': 'v'},
#   {'item': '理解', 'pos': 'v'},
#   {'item': '为', 'pos': 'v'},
#   {'item': 'Siri', 'pos': 'n'},
#   {'item': '或', 'pos': 'c'},
#   {'item': '各种', 'pos': 'r'},
#   {'item': 'Chat', 'pos': 'n'},
#   {'item': 'bot', 'pos': 'n'},
#   {'item': '所能', 'pos': 'v'},
#   {'item': '支持', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '聊天', 'pos': 'vn'},
#   {'item': '对话', 'pos': 'vn'},
#   {'item': '体验', 'pos': 'vn'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '1', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '任务', 'pos': 'n'},
#   {'item': '达成率', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '表征', 'pos': 'vn'},
#   {'item': '产品', 'pos': 'n'},
#   {'item': '功能', 'pos': 'n'},
#   {'item': '是否', 'pos': 'd'},
#   {'item': '有用', 'pos': 'a'},
#   {'item': '以及', 'pos': 'c'},
#   {'item': '功能', 'pos': 'n'},
#   {'item': '覆盖度', 'pos': 'n'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '比如', 'pos': 'v'},
#   {'item': '智能', 'pos': 'n'},
#   {'item': '客服', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '如果', 'pos': 'c'},
#   {'item': '这个', 'pos': 'r'},
#   {'item': 'Session', 'pos': 'n'},
#   {'item': '最终', 'pos': 'ad'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '以', 'pos': 'p'},
#   {'item': '接入', 'pos': 'v'},
#   {'item': '人工', 'pos': 'n'},
#   {'item': '为', 'pos': 'p'},
#   {'item': '结束', 'pos': 'vn'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '那', 'pos': 'r'},
#   {'item': '基本', 'pos': 'ad'},
#   {'item': '就', 'pos': 'd'},
#   {'item': '说明', 'pos': 'v'},
#   {'item': '机器', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '回答', 'pos': 'vn'},
#   {'item': '有问题', 'pos': 'v'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '或者', 'pos': 'c'},
#   {'item': '重复', 'pos': 'vd'},
#   {'item': '提供', 'pos': 'v'},
#   {'item': '给', 'pos': 'p'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '相同', 'pos': 'a'},
#   {'item': '答案', 'pos': 'n'},
#   {'item': '等等', 'pos': 'u'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '分', 'pos': 'v'},
#   {'item': '专项', 'pos': 'n'},
#   {'item': '或', 'pos': 'c'},
#   {'item': '分', 'pos': 'v'},
#   {'item': '意图', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '统计', 'pos': 'vn'},
#   {'item': '就', 'pos': 'd'},
#   {'item': '更多', 'pos': 'a'},
#   {'item': '了', 'pos': 'xc'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '展开', 'pos': 'v'},
# ...
#   {'item': '比例', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '即', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '前文', 'pos': 'r'},
#   {'item': '提', 'pos': 'v'},
#   {'item': '过', 'pos': 'u'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '任务', 'pos': 'n'},
#   {'item': '达成率', 'pos': 'nz'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '相关', 'pos': 'vn'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '重复', 'pos': 'vd'},
#   {'item': '问', 'pos': 'v'},
#   {'item': '同样', 'pos': 'a'},
#   {'item': '问题', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '比例', 'pos': 'n'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '没', 'pos': 'v'},
#   {'item': '答案', 'pos': 'n'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '之类', 'pos': 'u'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '比例', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '整体', 'pos': 'n'},
#   {'item': '来说', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '行业', 'pos': 'n'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': 'PR', 'pos': 'ti'},
#   {'item': '宣传', 'pos': 'v'},
#   {'item': '时', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '会', 'pos': 'v'},
#   {'item': '更多', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '提', 'pos': 'v'},
#   {'item': 'CPS', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '其他', 'pos': 'r'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '看起来', 'pos': 'vd'},
#   {'item': '可能', 'pos': 'v'},
#   {'item': '相对', 'pos': 'd'},
#   {'item': '太', 'pos': 'd'},
#   {'item': '琐碎', 'pos': 'a'},
#   {'item': '或', 'pos': 'c'},
#   {'item': '不够', 'pos': 'd'},
#   {'item': '高大上', 'pos': 'nr'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '但是', 'pos': 'c'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '实际', 'pos': 'a'},
#   {'item': '工作', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '可能', 'pos': 'v'},
#   {'item': 'CPS', 'pos': 'n'},
#   {'item': '更多', 'pos': 'ad'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '面向', 'pos': 'v'},
#   {'item': '闲聊型', 'pos': 'a'},
#   {'item': '对话', 'pos': 'vn'},
#   {'item': '系统', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '而', 'pos': 'c'},
#   {'item': '其他', 'pos': 'r'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '场景', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '可能', 'pos': 'v'},
#   {'item': '更', 'pos': 'd'},
#   {'item': '应该', 'pos': 'v'},
#   {'item': '从', 'pos': 'p'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '效果', 'pos': 'n'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '出发', 'pos': 'v'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '比如', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '如果', 'pos': 'c'},
#   {'item': '小孩子', 'pos': 'n'},
#   {'item': '哭', 'pos': 'v'},
#   {'item': '了', 'pos': 'xc'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '机器人', 'pos': 'n'},
#   {'item': '能够', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '哭声', 'pos': 'n'},
#   {'item': '安慰', 'pos': 'v'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '没', 'pos': 'v'},
#   {'item': '必要', 'pos': 'an'},
#   {'item': '对话', 'pos': 'v'},
#   {'item': '那么多', 'pos': 'a'},
#   {'item': '轮次', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '反而', 'pos': 'd'},
#   {'item': '应该', 'pos': 'v'},
#   {'item': '越', 'pos': 'd'},
#   {'item': '少', 'pos': 'a'},
#   {'item': '越好', 'pos': 'a'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '4', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '语料', 'pos': 'n'},
#   {'item': '自然', 'pos': 'ad'},
#   {'item': '度', 'pos': 'n'},
#   {'item': '和', 'pos': 'c'},
#   {'item': '人性化', 'pos': 'vn'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '程度', 'pos': 'n'},
#   {'item': '目前', 'pos': 't'},
#   {'item': '对于', 'pos': 'p'},
#   {'item': '这', 'pos': 'r'},
#   {'item': '类', 'pos': 'q'},
#   {'item': '问题', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '使用', 'pos': 'v'},
#   {'item': '人工', 'pos': 'n'},
#   {'item': '评估', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '方式', 'pos': 'n'},
#   {'item': '进行', 'pos': 'v'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '这里', 'pos': 'r'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '语料', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '通常', 'pos': 'd'},
#   {'item': '不是', 'pos': 'v'},
#   {'item': '单个', 'pos': 'a'},
#   {'item': '句子', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '而是', 'pos': 'v'},
#   {'item': '分为', 'pos': 'v'},
#   {'item': '单轮', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '问答', 'pos': 'vn'},
#   {'item': '对', 'pos': 'p'},
#   {'item': '或', 'pos': 'c'},
#   {'item': '多', 'pos': 'a'},
#   {'item': '轮', 'pos': 'q'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '一个', 'pos': 'm'},
#   {'item': 'session', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '一般', 'pos': 'ad'},
#   {'item': '来讲', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '评分', 'pos': 'vn'},
#   {'item': '范围', 'pos': 'n'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '1', 'pos': 'm'},
#   {'item': '~', 'pos': 'w'},
#   {'item': '5分', 'pos': 'm'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '1分', 'pos': 'm'},
#   {'item': '或', 'pos': 'c'},
#   {'item': '2分', 'pos': 'm'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '完全', 'pos': 'd'},
#   {'item': '答非所问', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '以及', 'pos': 'c'},
#   {'item': '含有', 'pos': 'v'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '友好', 'pos': 'a'},
#   {'item': '内容', 'pos': 'n'},
#   {'item': '或', 'pos': 'c'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '适合', 'pos': 'v'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '播报', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '特殊', 'pos': 'a'},
#   {'item': '内容', 'pos': 'n'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '3分', 'pos': 'm'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '基本', 'pos': 'ad'},
#   {'item': '可用', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '问答', 'pos': 'vn'},
#   {'item': '逻辑', 'pos': 'n'},
#   {'item': '正确', 'pos': 'a'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '4分', 'pos': 'm'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '能', 'pos': 'v'},
#   {'item': '解决', 'pos': 'v'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '问题', 'pos': 'n'},
#   {'item': '且', 'pos': 'c'},
#   {'item': '足够', 'pos': 'a'},
#   {'item': '精炼', 'pos': 'a'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '5分', 'pos': 'm'},
#   {'item': '：', 'pos': 'w'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '4分', 'pos': 'm'},
#   {'item': '基础', 'pos': 'n'},
#   {'item': '上', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '能', 'pos': 'v'},
#   {'item': '让', 'pos': 'v'},
#   {'item': '人', 'pos': 'n'},
#   {'item': '感受到', 'pos': 'v'},
#   {'item': '情感', 'pos': 'n'},
#   {'item': '及', 'pos': 'c'},
#   {'item': '人设', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '另外', 'pos': 'c'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '为了', 'pos': 'p'},
#   {'item': '消除', 'pos': 'v'},
#   {'item': '主观', 'pos': 'a'},
#   {'item': '偏差', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '采用', 'pos': 'v'},
#   {'item': '多', 'pos': 'a'},
#   {'item': '人', 'pos': 'n'},
#   {'item': '标注', 'pos': 'vn'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '去掉', 'pos': 'v'},
#   {'item': '极端值', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '方式', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '当前', 'pos': 't'},
#   {'item': '普遍', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '做法', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '5', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '整体', 'pos': 'n'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '数据', 'pos': 'n'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '常规', 'pos': 'n'},
#   {'item': '互联网', 'pos': 'n'},
#   {'item': '产品', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '都会', 'pos': 'v'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '整体', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '；', 'pos': 'w'},
#   {'item': 'AI', 'pos': 'nz'},
#   {'item': '产品', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一般', 'pos': 'ad'},
#   {'item': '也', 'pos': 'd'},
#   {'item': '会', 'pos': 'v'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '这个', 'pos': 'r'},
#   {'item': '角度', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '考量', 'pos': 'vn'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '1', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': 'DAU', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': 'Daily', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'Active', 'pos': 'xc'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': 'User', 'pos': 'xc'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '日', 'pos': 'q'},
#   {'item': '活跃', 'pos': 'a'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '数', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '简称', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '日活', 'pos': 'nz'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '特殊', 'pos': 'a'},
#   {'item': '场景', 'pos': 'n'},
#   {'item': '会', 'pos': 'v'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '变化', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '比如', 'pos': 'v'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '车载', 'pos': 'vn'},
#   {'item': '场景', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '会', 'pos': 'v'},
#   {'item': '统计', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': 'DAU占比', 'pos': 'nz'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '占', 'pos': 'v'},
#   {'item': '车机', 'pos': 'n'},
#   {'item': 'DAU', 'pos': 'nz'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '比例', 'pos': 'n'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '2', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '被', 'pos': 'p'},
#   {'item': '使用', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '意图', 'pos': 'n'},
#   {'item': '丰富', 'pos': 'a'},
#   {'item': '度', 'pos': 'n'},
#   {'item': '（', 'pos': 'w'},
#   {'item': '使用率', 'pos': 'n'},
#   {'item': '>', 'pos': 'w'},
#   {'item': 'X', 'pos': 'xc'},
#   {'item': '%', 'pos': 'xc'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '意图', 'pos': 'n'},
#   {'item': '个', 'pos': 'q'},
#   {'item': '数', 'pos': 'n'},
#   {'item': '）', 'pos': 'w'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '3', 'pos': 'm'},
#   {'item': '、', 'pos': 'w'},
#   {'item': '可', 'pos': 'v'},
#   {'item': '尝试', 'pos': 'v'},
#   {'item': '通过', 'pos': 'p'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '情绪', 'pos': 'n'},
#   {'item': '信息', 'pos': 'n'},
#   {'item': '和', 'pos': 'c'},
#   {'item': '语义', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '情绪', 'pos': 'n'},
#   {'item': '分类', 'pos': 'vn'},
#   {'item': '评估', 'pos': 'vn'},
#   {'item': '满意度', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '尤其', 'pos': 'd'},
#   {'item': '对于', 'pos': 'p'},
#   {'item': '生气', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '情绪', 'pos': 'n'},
#   {'item': '检测', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '这些', 'pos': 'r'},
#   {'item': '对话', 'pos': 'vn'},
#   {'item': '样本', 'pos': 'n'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '可以', 'pos': 'v'},
#   {'item': '挑选', 'pos': 'v'},
#   {'item': '出来', 'pos': 'v'},
#   {'item': '分析', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '比如', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '公司', 'pos': 'n'},
#   {'item': '会', 'pos': 'v'},
#   {'item': '统计', 'pos': 'v'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '多少', 'pos': 'r'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '骂人', 'pos': 'v'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '以此', 'pos': 'd'},
#   {'item': '大概', 'pos': 'd'},
#   {'item': '了解', 'pos': 'v'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '情绪', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '还', 'pos': 'd'},
#   {'item': '比如', 'pos': 'v'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '在', 'pos': 'p'},
#   {'item': '同花顺', 'pos': 'nt'},
#   {'item': '手机', 'pos': 'n'},
#   {'item': '客户端', 'pos': 'n'},
#   {'item': '中', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '拉', 'pos': 'v'},
#   {'item': '到', 'pos': 'v'},
#   {'item': '最', 'pos': 'd'},
#   {'item': '底下', 'pos': 'f'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '有', 'pos': 'v'},
#   {'item': '个', 'pos': 'q'},
#   {'item': '一站式', 'pos': 'a'},
#   {'item': '问答', 'pos': 'vn'},
#   {'item': '功能', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '用户', 'pos': 'n'},
#   {'item': '对', 'pos': 'p'},
#   {'item': '它', 'pos': 'r'},
#   {'item': '说', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '怎么', 'pos': 'r'},
#   {'item': '登录', 'pos': 'v'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '上去', 'pos': 'v'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '和', 'pos': 'c'},
#   {'item': '说', 'pos': 'v'},
#   {'item': '“', 'pos': 'w'},
#   {'item': '怎么', 'pos': 'r'},
#   {'item': '老是', 'pos': 'd'},
#   {'item': '登录', 'pos': 'v'},
#   {'item': '不', 'pos': 'd'},
#   {'item': '上去', 'pos': 'v'},
#   {'item': '”', 'pos': 'w'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '返回', 'pos': 'vn'},
#   {'item': '结果', 'pos': 'n'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '不一样', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '后者', 'pos': 'r'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '系统', 'pos': 'n'},
#   {'item': '检测', 'pos': 'v'},
#   {'item': '到', 'pos': 'v'},
#   {'item': '负面', 'pos': 'a'},
#   {'item': '情绪', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '会', 'pos': 'v'},
#   {'item': '提示', 'pos': 'v'},
#   {'item': '转接', 'pos': 'v'},
#   {'item': '人工', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '结语', 'pos': 'n'},
#   {'item': ' ', 'pos': 'w'},
#   {'item': '本', 'pos': 'r'},
#   {'item': '篇', 'pos': 'q'},
#   {'item': '分享', 'pos': 'vn'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '介绍', 'pos': 'v'},
#   {'item': '了', 'pos': 'u'},
#   {'item': '现在', 'pos': 't'},
#   {'item': '行业', 'pos': 'n'},
#   {'item': '内', 'pos': 'f'},
#   {'item': '对', 'pos': 'p'},
#   {'item': '语音', 'pos': 'n'},
#   {'item': '交互', 'pos': 'v'},
#   {'item': '系统', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '常见', 'pos': 'a'},
#   {'item': '评价', 'pos': 'vn'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '一方面', 'pos': 'c'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '是', 'pos': 'v'},
#   {'item': '提供', 'pos': 'v'},
#   {'item': '给', 'pos': 'p'},
#   {'item': '各位', 'pos': 'r'},
#   {'item': 'AI', 'pos': 'nz'},
#   {'item': '产品经理', 'pos': 'ti'},
#   {'item': '以', 'pos': 'p'},
#   {'item': '最', 'pos': 'd'},
#   {'item': '接', 'pos': 'v'},
#   {'item': '地气', 'pos': 'n'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '相关', 'pos': 'vn'},
#   {'item': '信息', 'pos': 'n'},
#   {'item': '；', 'pos': 'w'},
#   {'item': '另', 'pos': 'c'},
#   {'item': '一方面', 'pos': 'c'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '也是', 'pos': 'v'},
#   {'item': '希望', 'pos': 'v'},
#   {'item': '大家', 'pos': 'r'},
#   {'item': '基于', 'pos': 'p'},
#   {'item': '这些', 'pos': 'r'},
#   {'item': '指标', 'pos': 'n'},
#   {'item': '，', 'pos': 'w'},
#   {'item': '打造', 'pos': 'v'},
#   {'item': '出', 'pos': 'v'},
#   {'item': '更好', 'pos': 'a'},
#   {'item': '的', 'pos': 'u'},
#   {'item': '产品', 'pos': 'n'},
#   {'item': '体验', 'pos': 'vn'},
#   {'item': '效果', 'pos': 'n'},
#   {'item': '[', 'pos': 'w'}],
#  [{'item': '。', 'pos': 'w'}, {'item': '[', 'pos': 'w'}],
#  [{'item': '[', 'pos': 'w'}]]
